# %%
children = ["Andrew","Laura","Joe"]
lol_children = [[c, len(c)]  for c in children]
lol_children
# Out:
# [['Andrew', 6], ['Laura', 5], ['Joe', 3]]

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (0.25.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\programdata\anaconda3\lib\site-packages (from pandas) (1.16.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2019.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)

# %%
import pandas as pd
df_lol_children = pd.DataFrame(lol_children,columns = ["child","charlen"])
df_lol_children
# Out:
#     child  charlen
# 0  Andrew        6
# 1   Laura        5
# 2     Joe        3

# %%
len_char = [len(c) for c in children]
d_children = {"child": children, "charlen": len_char}
d_children
# Out:
# {'child': ['Andrew', 'Laura', 'Joe'], 'charlen': [6, 5, 3]}

# %%
df_d_children = pd.DataFrame(d_children)
df_d_children
# Out:
#     child  charlen
# 0  Andrew        6
# 1   Laura        5
# 2     Joe        3

# %%
df_d_children.info()
import pandas as pd
poll_url = 'http://projects.fivethirtyeight.com/general-model/president_general_polls_2016.csv'
polls = pd.read_csv(poll_url)
import datetime as datetime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
# child      3 non-null object
# charlen    3 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
polls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12624 entries, 0 to 12623
# Data columns (total 27 columns):
# cycle               12624 non-null int64
# branch              12624 non-null object
# type                12624 non-null object
# matchup             12624 non-null object
# forecastdate        12624 non-null object
# state               12624 non-null object
# startdate           12624 non-null object
# enddate             12624 non-null object
# pollster            12624 non-null object
# grade               11337 non-null object
# samplesize          12621 non-null float64
# population          12624 non-null object
# poll_wt             12624 non-null float64
# rawpoll_clinton     12624 non-null float64
# rawpoll_trump       12624 non-null float64
# rawpoll_johnson     8397 non-null float64
# rawpoll_mcmullin    90 non-null float64
# adjpoll_clinton     12624 non-null float64
# adjpoll_trump       12624 non-null float64
# adjpoll_johnson     8397 non-null float64
# adjpoll_mcmullin    90 non-null float64
# multiversions       36 non-null object
# url                 12621 non-null object
# poll_id             12624 non-null int64
# question_id         12624 non-null int64
# createddate         12624 non-null object
# timestamp           12624 non-null object
# dtypes: float64(10), int64(3), object(14)
# memory usage: 2.6+ MB

# %%
polls.startdate.value_counts()
# Out:
# 10/20/2016    480
# 11/1/2016     465
# 10/25/2016    408
# 10/4/2016     351
# 10/27/2016    300
#              ...
# 6/29/2016       3
# 1/16/2016       3
# 2/7/2016        3
# 1/29/2016       3
# 12/31/2015      3
# Name: startdate, Length: 352, dtype: int64

# %%
polls["startdate"] = pd.to_datetime(polls["startdate"])
polls.forecastdate.head(5)
# Out:
# 0    11/8/16
# 1    11/8/16
# 2    11/8/16
# 3    11/8/16
# 4    11/8/16
# Name: forecastdate, dtype: object

# %%
polls.sort_values('enddate', ascending=False, inplace=True)
polls.head()
# Out:
#        cycle     branch        type                        matchup  \
# 3129    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 7616    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 6013    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 11796   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 11545   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate state  startdate   enddate                  pollster grade  \
# 3129       11/8/16  U.S. 2016-09-03  9/9/2016      CVOTER International    C+
# 7616       11/8/16  U.S. 2016-09-07  9/9/2016  The Times-Picayune/Lucid   NaN
# 6013       11/8/16  Utah 2016-09-01  9/9/2016    Dan Jones & Associates    C+
# 11796      11/8/16  U.S. 2016-09-07  9/9/2016  The Times-Picayune/Lucid   NaN
# 11545      11/8/16  U.S. 2016-09-03  9/9/2016      CVOTER International    C+
#
#        ...  adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 3129   ...         44.72046      46.23692              NaN               NaN
# 7616   ...         45.70159      43.74136         2.863258               NaN
# 6013   ...         25.65818      41.79232         8.761094           11.0605
# 11796  ...         45.70411      43.73750         2.889425               NaN
# 11545  ...         44.69583      46.21712              NaN               NaN
#
#        multiversions                                                url  \
# 3129             NaN  http://www.upi.com/Top_News/US/2016/09/12/UPIC...
# 7616             NaN          https://luc.id/2016-presidential-tracker/
# 6013             NaN  http://utahpolicy.com/index.php/features/today...
# 11796            NaN          https://luc.id/2016-presidential-tracker/
# 11545            NaN  http://www.upi.com/Top_News/US/2016/09/12/UPIC...
#
#        poll_id  question_id  createddate             timestamp
# 3129     45708        71316      9/12/16  09:35:33  8 Nov 2016
# 7616     46210        72269      9/28/16  09:24:53  8 Nov 2016
# 6013     45706        71311      9/12/16  09:24:53  8 Nov 2016
# 11796    46210        72269      9/28/16  09:14:14  8 Nov 2016
# 11545    45708        71316      9/12/16  09:14:14  8 Nov 2016
#
# [5 rows x 27 columns]

# %%
polls.tail()
# Out:
#        cycle     branch        type                        matchup  \
# 12446   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 4019    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 4044    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 8252    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 12460   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate state  startdate    enddate         pollster grade  ...  \
# 12446      11/8/16  U.S. 2016-01-08  1/10/2016  Morning Consult   NaN  ...
# 4019       11/8/16  U.S. 2016-01-06  1/10/2016            Ipsos    A-  ...
# 4044       11/8/16  U.S. 2015-12-28   1/1/2016            Ipsos    A-  ...
# 8252       11/8/16  U.S. 2015-12-28   1/1/2016            Ipsos    A-  ...
# 12460      11/8/16  U.S. 2015-12-28   1/1/2016            Ipsos    A-  ...
#
#        adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 12446         42.94417      47.29964              NaN               NaN
# 4019          40.89772      35.33364              NaN               NaN
# 4044          36.33124      40.50216              NaN               NaN
# 8252          36.38155      40.56037              NaN               NaN
# 12460         36.34617      40.48936              NaN               NaN
#
#        multiversions                                                url  \
# 12446            NaN  http://morningconsult.com/polls/new-poll-gop-c...
# 4019             NaN  http://polling.reuters.com/#poll/TM651Y15_13/f...
# 4044             NaN  http://polling.reuters.com/#poll/TM651Y15_13/f...
# 8252             NaN  http://polling.reuters.com/#poll/TM651Y15_13/f...
# 12460            NaN  http://polling.reuters.com/#poll/TM651Y15_13/f...
#
#        poll_id  question_id  createddate             timestamp
# 12446    35863        48180      1/14/16  09:14:14  8 Nov 2016
# 4019     35866        65434       5/5/16  09:35:33  8 Nov 2016
# 4044     44026        65443       5/5/16  09:35:33  8 Nov 2016
# 8252     44026        65443       5/5/16  09:24:53  8 Nov 2016
# 12460    44026        65443       5/5/16  09:14:14  8 Nov 2016
#
# [5 rows x 27 columns]

# %%
polls.drop
# Out:
# <bound method DataFrame.drop of        cycle     branch        type                        matchup  \
# 3129    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 7616    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 6013    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 11796   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 11545   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 12446   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 4019    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 4044    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 8252    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 12460   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate state  startdate    enddate                  pollster  \
# 3129       11/8/16  U.S. 2016-09-03   9/9/2016      CVOTER International
# 7616       11/8/16  U.S. 2016-09-07   9/9/2016  The Times-Picayune/Lucid
# 6013       11/8/16  Utah 2016-09-01   9/9/2016    Dan Jones & Associates
# 11796      11/8/16  U.S. 2016-09-07   9/9/2016  The Times-Picayune/Lucid
# 11545      11/8/16  U.S. 2016-09-03   9/9/2016      CVOTER International
# ...            ...   ...        ...        ...                       ...
# 12446      11/8/16  U.S. 2016-01-08  1/10/2016           Morning Consult
# 4019       11/8/16  U.S. 2016-01-06  1/10/2016                     Ipsos
# 4044       11/8/16  U.S. 2015-12-28   1/1/2016                     Ipsos
# 8252       11/8/16  U.S. 2015-12-28   1/1/2016                     Ipsos
# 12460      11/8/16  U.S. 2015-12-28   1/1/2016                     Ipsos
#
#       grade  ...  adjpoll_clinton adjpoll_trump  adjpoll_johnson  \
# 3129     C+  ...         44.72046      46.23692              NaN
# 7616    NaN  ...         45.70159      43.74136         2.863258
# 6013     C+  ...         25.65818      41.79232         8.761094
# 11796   NaN  ...         45.70411      43.73750         2.889425
# 11545    C+  ...         44.69583      46.21712              NaN
# ...     ...  ...              ...           ...              ...
# 12446   NaN  ...         42.94417      47.29964              NaN
# 4019     A-  ...         40.89772      35.33364              NaN
# 4044     A-  ...         36.33124      40.50216              NaN
# 8252     A-  ...         36.38155      40.56037              NaN
# 12460    A-  ...         36.34617      40.48936              NaN
#
#        adjpoll_mcmullin  multiversions  \
# 3129                NaN            NaN
# 7616                NaN            NaN
# 6013            11.0605            NaN
# 11796               NaN            NaN
# 11545               NaN            NaN
# ...                 ...            ...
# 12446               NaN            NaN
# 4019                NaN            NaN
# 4044                NaN            NaN
# 8252                NaN            NaN
# 12460               NaN            NaN
#
#                                                      url  poll_id  \
# 3129   http://www.upi.com/Top_News/US/2016/09/12/UPIC...    45708
# 7616           https://luc.id/2016-presidential-tracker/    46210
# 6013   http://utahpolicy.com/index.php/features/today...    45706
# 11796          https://luc.id/2016-presidential-tracker/    46210
# 11545  http://www.upi.com/Top_News/US/2016/09/12/UPIC...    45708
# ...                                                  ...      ...
# 12446  http://morningconsult.com/polls/new-poll-gop-c...    35863
# 4019   http://polling.reuters.com/#poll/TM651Y15_13/f...    35866
# 4044   http://polling.reuters.com/#poll/TM651Y15_13/f...    44026
# 8252   http://polling.reuters.com/#poll/TM651Y15_13/f...    44026
# 12460  http://polling.reuters.com/#poll/TM651Y15_13/f...    44026
#
#        question_id  createddate             timestamp
# 3129         71316      9/12/16  09:35:33  8 Nov 2016
# 7616         72269      9/28/16  09:24:53  8 Nov 2016
# 6013         71311      9/12/16  09:24:53  8 Nov 2016
# 11796        72269      9/28/16  09:14:14  8 Nov 2016
# 11545        71316      9/12/16  09:14:14  8 Nov 2016
# ...            ...          ...                   ...
# 12446        48180      1/14/16  09:14:14  8 Nov 2016
# 4019         65434       5/5/16  09:35:33  8 Nov 2016
# 4044         65443       5/5/16  09:35:33  8 Nov 2016
# 8252         65443       5/5/16  09:24:53  8 Nov 2016
# 12460        65443       5/5/16  09:14:14  8 Nov 2016
#
# [12624 rows x 27 columns]>

# %%
polls = polls.rename(columns={'adjpoll_clinton':'Clinton',
                      'adjpoll_trump':'Trump'})

# %%
num = [f for f in range(0,12624)]

# %%
foo = polls.loc[0:100:10,'state':'grade'].index

# %%
print (polls)
# Out:
#        cycle     branch        type                        matchup  \
# 3129    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 7616    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 6013    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 11796   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 11545   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 12446   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 4019    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 4044    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 8252    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 12460   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate state  startdate    enddate                  pollster  \
# 3129       11/8/16  U.S. 2016-09-03   9/9/2016      CVOTER International
# 7616       11/8/16  U.S. 2016-09-07   9/9/2016  The Times-Picayune/Lucid
# 6013       11/8/16  Utah 2016-09-01   9/9/2016    Dan Jones & Associates
# 11796      11/8/16  U.S. 2016-09-07   9/9/2016  The Times-Picayune/Lucid
# 11545      11/8/16  U.S. 2016-09-03   9/9/2016      CVOTER International
# ...            ...   ...        ...        ...                       ...
# 12446      11/8/16  U.S. 2016-01-08  1/10/2016           Morning Consult
# 4019       11/8/16  U.S. 2016-01-06  1/10/2016                     Ipsos
# 4044       11/8/16  U.S. 2015-12-28   1/1/2016                     Ipsos
# 8252       11/8/16  U.S. 2015-12-28   1/1/2016                     Ipsos
# 12460      11/8/16  U.S. 2015-12-28   1/1/2016                     Ipsos
#
#       grade  ...   Clinton     Trump  adjpoll_johnson  adjpoll_mcmullin  \
# 3129     C+  ...  44.72046  46.23692              NaN               NaN
# 7616    NaN  ...  45.70159  43.74136         2.863258               NaN
# 6013     C+  ...  25.65818  41.79232         8.761094           11.0605
# 11796   NaN  ...  45.70411  43.73750         2.889425               NaN
# 11545    C+  ...  44.69583  46.21712              NaN               NaN
# ...     ...  ...       ...       ...              ...               ...
# 12446   NaN  ...  42.94417  47.29964              NaN               NaN
# 4019     A-  ...  40.89772  35.33364              NaN               NaN
# 4044     A-  ...  36.33124  40.50216              NaN               NaN
# 8252     A-  ...  36.38155  40.56037              NaN               NaN
# 12460    A-  ...  36.34617  40.48936              NaN               NaN
#
#        multiversions                                                url  \
# 3129             NaN  http://www.upi.com/Top_News/US/2016/09/12/UPIC...
# 7616             NaN          https://luc.id/2016-presidential-tracker/
# 6013             NaN  http://utahpolicy.com/index.php/features/today...
# 11796            NaN          https://luc.id/2016-presidential-tracker/
# 11545            NaN  http://www.upi.com/Top_News/US/2016/09/12/UPIC...
# ...              ...                                                ...
# 12446            NaN  http://morningconsult.com/polls/new-poll-gop-c...
# 4019             NaN  http://polling.reuters.com/#poll/TM651Y15_13/f...
# 4044             NaN  http://polling.reuters.com/#poll/TM651Y15_13/f...
# 8252             NaN  http://polling.reuters.com/#poll/TM651Y15_13/f...
# 12460            NaN  http://polling.reuters.com/#poll/TM651Y15_13/f...
#
#        poll_id  question_id  createddate             timestamp
# 3129     45708        71316      9/12/16  09:35:33  8 Nov 2016
# 7616     46210        72269      9/28/16  09:24:53  8 Nov 2016
# 6013     45706        71311      9/12/16  09:24:53  8 Nov 2016
# 11796    46210        72269      9/28/16  09:14:14  8 Nov 2016
# 11545    45708        71316      9/12/16  09:14:14  8 Nov 2016
# ...        ...          ...          ...                   ...
# 12446    35863        48180      1/14/16  09:14:14  8 Nov 2016
# 4019     35866        65434       5/5/16  09:35:33  8 Nov 2016
# 4044     44026        65443       5/5/16  09:35:33  8 Nov 2016
# 8252     44026        65443       5/5/16  09:24:53  8 Nov 2016
# 12460    44026        65443       5/5/16  09:14:14  8 Nov 2016
#
# [12624 rows x 27 columns]

# %%
len(polls)
# Out:
# 12624
