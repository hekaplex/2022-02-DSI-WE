# %%
#import Python library used for working with arrays; domain of linear algebra, etc.
import numpy as np
#import python library
import pandas as pd
#All of the statistics functions are located in the scipy sub-package 
from scipy import stats
#podbc is an open source Python module that makes accessing ODBC databases simple. how we connect to SQL
import pyodbc
#pyplot is intended for interactive plots and simple cases of programmatic plot generation
import matplotlib as plt

# %%
#Code not working below; possible DSN incorrect, however, I used the explicit Conn in future code.
#conn = pyodbc.connect('DSN=DSI_DSN_SQL')
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7868/2709649992.py in <module>
# ----> 1 conn = pyodbc.connect('DSN=DSI_DSN_SQL')
#
# InterfaceError: ('28000', "[28000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Login failed for user ''. (18456) (SQLDriverConnect); [28000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Login failed for user ''. (18456)")

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is B426-88EF
#
#  Directory of c:\Users\teres\Documents\2022-02-DSI-WE\butleranalyticsllc\py
#
# 06/11/2022  10:58 AM    <DIR>          .
# 06/04/2022  06:36 PM    <DIR>          ..
# 06/05/2022  04:21 PM             2,983 Assignment1.ipynb
# 06/05/2022  06:01 PM             2,832 Assignment2.ipynb
# 06/07/2022  11:10 PM             4,853 Assignment3.ipynb
# 06/07/2022  11:08 PM               274 da.txt
# 06/07/2022  11:08 PM               528 de.txt
# 06/07/2022  11:08 PM               523 ds.txt
# 06/04/2022  05:36 PM            10,130 intro.ipynb
# 06/11/2022  10:57 AM                 0 SQLtoPandas.ipynb
# 06/07/2022  11:10 PM                 8 students.txt
#                9 File(s)         22,131 bytes
#                2 Dir(s)  39,058,845,696 bytes free

# %%
import pyodbc
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=2022dsiwd.database.windows.net;DATABASE=AdventureWorks2019;UID=admin2022dsiwd;PWD=Divergence!2022dsiwd')

# %%
sql = "select top 100 * from [Sales].[SalesOrderHeader] "
data = pd.read_sql(sql,conn)
data
# Out:
#     SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0          43659               8 2011-05-31 2011-06-12 2011-06-07       5
# 1          43660               8 2011-05-31 2011-06-12 2011-06-07       5
# 2          43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 3          43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 4          43663               8 2011-05-31 2011-06-12 2011-06-07       5
# ..           ...             ...        ...        ...        ...     ...
# 95         43754               8 2011-06-14 2011-06-26 2011-06-21       5
# 96         43755               8 2011-06-14 2011-06-26 2011-06-21       5
# 97         43756               8 2011-06-14 2011-06-26 2011-06-21       5
# 98         43757               8 2011-06-14 2011-06-26 2011-06-21       5
# 99         43758               8 2011-06-15 2011-06-27 2011-06-22       5
#
#     OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  ...  \
# ...
