-- %% [markdown]
-- # [pricingdatamart]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [pricingdatamart]    Script Date: 5/17/2022 11:50:23 AM ******/
CREATE DATABASE [pricingdatamart]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'pricingdatamart', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\pricingdatamart.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'pricingdatamart_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\pricingdatamart_log.ldf' , SIZE = 73728KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [pricingdatamart] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [pricingdatamart].[dbo].[sp_fulltext_database] @action = 'disable'
end
GO
ALTER DATABASE [pricingdatamart] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [pricingdatamart] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [pricingdatamart] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [pricingdatamart] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [pricingdatamart] SET ARITHABORT OFF 
GO
ALTER DATABASE [pricingdatamart] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [pricingdatamart] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [pricingdatamart] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [pricingdatamart] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [pricingdatamart] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [pricingdatamart] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [pricingdatamart] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [pricingdatamart] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [pricingdatamart] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [pricingdatamart] SET  ENABLE_BROKER 
GO
ALTER DATABASE [pricingdatamart] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [pricingdatamart] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [pricingdatamart] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [pricingdatamart] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [pricingdatamart] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [pricingdatamart] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [pricingdatamart] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [pricingdatamart] SET RECOVERY FULL 
GO
ALTER DATABASE [pricingdatamart] SET  MULTI_USER 
GO
ALTER DATABASE [pricingdatamart] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [pricingdatamart] SET DB_CHAINING OFF 
GO
ALTER DATABASE [pricingdatamart] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [pricingdatamart] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [pricingdatamart] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [pricingdatamart] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'pricingdatamart', N'ON'
GO
ALTER DATABASE [pricingdatamart] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[StripToNumeric]

-- %%
USE [pricingdatamart]
GO

-- %%
/****** Object:  UserDefinedFunction [dbo].[StripToNumeric]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [dbo].[StripToNumeric] (@INPUT varchar(100))
RETURNS int
WITH EXECUTE AS CALLER
AS
BEGIN
	DECLARE @StripToNumeric int
	DECLARE @Iteration int
	DECLARE @Loop int
	DECLARE @check char(1)

     SET @Iteration = 0
	WHILE @Iteration < LEN(@INPUT)
	BEGIN
			SET @Iteration = @Iteration + 1
	set @check = substring(@input,@Iteration,1)
	if charindex(@check,'0123456789') = 0
		begin
		set @INPUT = REPLACE(@INPUT,@check,'')
		END
	END
	SET @StripToNumeric = @INPUT
     RETURN(@StripToNumeric)
END
GO

-- %% [markdown]
-- # [dbo].[calcGoldBook]

-- %%
/****** Object:  Table [dbo].[calcGoldBook]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[calcGoldBook](
	[CatalogNumber] [varchar](50) NULL,
	[ProductLine] [varchar](50) NULL,
	[ProductGroup] [varchar](50) NULL,
	[EffectiveDate] [datetime] NULL,
	[ExpirationDate] [datetime] NULL,
	[PriceMatrix] [varchar](10) NULL,
	[ABCMatrix] [varchar](10) NULL,
	[ExtPrice] [numeric](19, 8) NULL,
	[UOM] [int] NULL,
	[LogID] [int] NULL,
	[productkey] [int] NULL,
	[zUOM] [int] NULL,
	[unitgoldbookprice] [numeric](16, 9) NULL,
	[LatestPrice] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[calcratio]

-- %%
/****** Object:  Table [dbo].[calcratio]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[calcratio](
	[customerkey] [int] NOT NULL,
	[ProdGrp] [varchar](203) NULL,
	[dollars] [decimal](38, 8) NULL,
	[qty] [decimal](38, 8) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimABCMatrix]

-- %%
/****** Object:  Table [dbo].[DimABCMatrix]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimABCMatrix](
	[abccode] [varchar](10) NULL,
	[abcdesc] [varchar](10) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[dimbusinessunit]

-- %%
/****** Object:  Table [dbo].[dimbusinessunit]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[dimbusinessunit](
	[businessunit] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimCustomer]

-- %%
/****** Object:  Table [dbo].[DimCustomer]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimCustomer](
	[Customerkey] [int] IDENTITY(1,1) NOT NULL,
	[CustomerNumber] [varchar](50) NOT NULL,
	[CustName] [varchar](100) NULL,
	[CustChainCode] [varchar](100) NULL,
	[CustChainDescr] [varchar](100) NULL,
	[CustDistCode] [varchar](100) NULL,
	[CustDistDesc] [varchar](100) NULL,
	[CustRegCode] [varchar](100) NULL,
	[CustRegDesc] [varchar](100) NULL,
	[SalesOfficeCode] [varchar](100) NULL,
	[SalesOfficeDesc] [varchar](100) NULL,
	[ParentCustomerNumber] [varchar](100) NULL,
	[BusinessUnitId] [varchar](100) NULL,
	[DomSalesOffice] [varchar](100) NULL,
	[CustVelocity] [nvarchar](50) NULL,
	[RowIsCurrent] [tinyint] NULL,
	[RowStartDate] [datetime] NULL,
	[RowEndDate] [datetime] NULL,
	[LogID] [int] NULL,
	[DomSalesOfficeCode] [varchar](100) NULL,
	[VelocityKey] [int] NULL,
	[Source] [varchar](50) NULL,
	[ChainDistrictKey] [int] NULL,
	[ChainKey] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimDate]

-- %%
/****** Object:  Table [dbo].[DimDate]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimDate](
	[DATEKEY] [numeric](18, 0) NOT NULL,
	[Date] [datetime] NULL,
	[Year] [int] NULL,
	[Quarter] [varchar](20) NULL,
	[Month] [varchar](20) NULL,
	[Day] [varchar](10) NULL,
	[FiscalQuarter] [varchar](20) NULL,
	[FiscalYear] [int] NULL,
	[FiscalMonth] [varchar](20) NULL,
	[isWeekend] [bit] NULL,
	[isHoliday] [bit] NULL,
	[FiscalQuarterKey] [int] NULL,
	[MonthKey] [int] NULL,
	[FiscalMonthKey] [int] NULL,
	[QuarterKey] [int] NULL,
	[DayKey] [int] NULL,
	[LOGID] [int] NULL,
	[CompletedMonth] [int] NULL,
 CONSTRAINT [PK_DIMDATE] PRIMARY KEY CLUSTERED 
(
	[DATEKEY] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimOrderSize]

-- %%
/****** Object:  Table [dbo].[DimOrderSize]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimOrderSize](
	[OrderSizeKey] [int] NOT NULL,
	[OrderSize] [varchar](20) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[dimPriceSource]

-- %%
/****** Object:  Table [dbo].[dimPriceSource]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[dimPriceSource](
	[PriceSource] [varchar](20) NULL,
	[PriceSourceDesc] [varchar](21) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimProduct]

-- %%
/****** Object:  Table [dbo].[DimProduct]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimProduct](
	[Catalognumber] [varchar](50) NULL,
	[ProdCatalogDesc] [varchar](100) NULL,
	[MarketPlanningGroup] [varchar](100) NULL,
	[MarketPlanningGroupDesc] [varchar](100) NULL,
	[ProdAssociation] [varchar](100) NULL,
	[ProdAssociationDesc] [varchar](100) NULL,
	[prodline] [varchar](100) NULL,
	[prodlinedesc] [varchar](100) NULL,
	[prodgroup] [varchar](100) NULL,
	[prodgroupdesc] [varchar](100) NULL,
	[ProductStatus] [varchar](8) NULL,
	[ProductPriority] [varchar](8) NULL,
	[Replacement_cat] [varchar](100) NULL,
	[where_made_id] [varchar](100) NULL,
	[Material] [numeric](12, 4) NULL,
	[Freight] [numeric](12, 4) NULL,
	[Material_Overhead] [numeric](12, 4) NULL,
	[Direct_Labor] [numeric](12, 4) NULL,
	[Variable_Overhead] [numeric](12, 4) NULL,
	[Fixed_Overhead] [numeric](12, 4) NULL,
	[productnew] [varchar](8) NULL,
	[productvelocity] [varchar](50) NULL,
	[pgvelocitykey] [int] NULL,
	[plvelocitykey] [int] NULL,
	[ProductLineBucket] [varchar](50) NULL,
	[ProductGroupBucket] [varchar](50) NULL,
	[velocitykey] [int] NULL,
	[productkey] [int] IDENTITY(1,1) NOT NULL,
	[prodgroupdv] [varchar](50) NULL,
	[unitprice] [numeric](16, 9) NULL,
	[itemcost] [numeric](16, 9) NULL,
	[gbuom] [int] NULL,
	[zuom] [int] NULL,
	[CatNum_DV] [numeric](38, 10) NULL,
	[ProdVel_DV] [numeric](38, 10) NULL,
	[ProdGrp_DV] [numeric](38, 10) NULL,
	[ProdGrpVel_DV] [numeric](38, 10) NULL,
	[ProdLine_DV] [numeric](38, 10) NULL,
	[gbunitprice] [numeric](38, 0) NULL,
	[LogID] [int] NULL,
	[Source] [varchar](50) NULL,
	[wheremadekey] [int] NULL,
	[Exclusion] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimQuoteFlag]

-- %%
/****** Object:  Table [dbo].[DimQuoteFlag]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimQuoteFlag](
	[QuoteFlagKey] [int] NULL,
	[QuoteFlagDesc] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimRQM]

-- %%
/****** Object:  Table [dbo].[DimRQM]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimRQM](
	[RQMName] [varchar](255) NULL,
	[Region_id] [varchar](35) NULL,
	[region_desc] [varchar](35) NULL,
	[SalesOfficeAgentCode] [varchar](100) NULL,
	[SalesOfficeAgentDescription] [varchar](100) NULL,
	[rqmcode] [varchar](20) NULL,
	[BusinessUnitId] [varchar](20) NULL,
	[BusinessUnitDesc] [varchar](20) NULL,
	[RowIsCurrent] [int] NULL,
	[RowStartDate] [datetime] NULL,
	[RowEndDate] [datetime] NULL,
	[LogID] [int] NULL,
	[RQMKey] [int] IDENTITY(1,1) NOT NULL,
	[Source] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimSpa]

-- %%
/****** Object:  Table [dbo].[DimSpa]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimSpa](
	[SPaKey] [int] NULL,
	[Credit] [varchar](5) NULL,
	[CreditType] [varchar](20) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimTimeUtility]

-- %%
/****** Object:  Table [dbo].[DimTimeUtility]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimTimeUtility](
	[TimeUtilityKey] [tinyint] NOT NULL,
	[TimeUtilityDesc] [varchar](10) NOT NULL,
 CONSTRAINT [PK_DIMTIMEUTILITY] PRIMARY KEY CLUSTERED 
(
	[TimeUtilityKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimWaterfall]

-- %%
/****** Object:  Table [dbo].[DimWaterfall]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimWaterfall](
	[wfCode] [varchar](255) NULL,
	[wfDescription] [varchar](255) NULL,
	[wfParentCode] [varchar](255) NULL,
	[wfRollup] [varchar](255) NULL,
	[wfDisplayOrder] [float] NULL,
	[wfRevOrExp] [float] NULL,
	[wfCustomMember] [varchar](8000) NULL,
	[wfLevel] [varchar](255) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FactOrders]

-- %%
/****** Object:  Table [dbo].[FactOrders]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FactOrders](
	[OrderKey] [bigint] NULL,
	[OrderId] [varchar](50) NULL,
	[OrderLineId] [int] NULL,
	[CurrencyKey] [int] NOT NULL,
	[CustomerKey] [int] NOT NULL,
	[ProductKey] [int] NOT NULL,
	[RQMKey] [int] NOT NULL,
	[DateKey] [int] NOT NULL,
	[OrderSizeKey] [int] NOT NULL,
	[PriceBandKey] [int] NOT NULL,
	[QuantityBandKey] [int] NOT NULL,
	[QuoteFlagKey] [int] NULL,
	[SpaKey] [int] NOT NULL,
	[TimeUtilityKey] [int] NOT NULL,
	[WinKey] [int] NOT NULL,
	[PriceSource] [varchar](20) NULL,
	[SalesDollars] [decimal](19, 8) NULL,
	[Quantity] [decimal](19, 8) NULL,
	[UOM] [int] NULL,
	[ExtCost] [decimal](19, 8) NULL,
	[Commissions] [decimal](19, 8) NULL,
	[PaymentTerms] [decimal](19, 8) NULL,
	[Rebates_VID] [decimal](19, 8) NOT NULL,
	[Rebates_Concession] [decimal](19, 8) NULL,
	[MinimumOrderCharge] [decimal](19, 8) NULL,
	[BusinessUnit] [varchar](50) NOT NULL,
	[LineType] [char](10) NOT NULL,
	[QuoteNumber] [int] NULL,
	[QuoteFlag] [varchar](50) NOT NULL,
	[QuoteType] [varchar](50) NOT NULL,
	[RegionId] [int] NOT NULL,
	[PeerPrice] [decimal](19, 8) NULL,
	[ExtendedPeerPrice] [decimal](19, 8) NULL,
	[StandardCost] [decimal](19, 8) NULL,
	[PeerPriceLevel] [smallint] NULL,
	[GoldBookPrice] [decimal](19, 8) NULL,
	[NetPromoPrice] [decimal](19, 8) NULL,
	[PocketMargin] [decimal](19, 8) NULL,
	[GrossMargin] [decimal](19, 8) NULL,
	[Margin] [decimal](19, 8) NULL,
	[OrderSizeBucket] [varchar](50) NULL,
	[InsertDate] [datetime] NULL,
	[UpdateDate] [datetime] NULL,
	[LOGID] [int] NULL,
	[PriceMatrix] [varchar](10) NULL,
	[ABCMatrix] [varchar](10) NULL,
	[tnborderid] [varchar](100) NULL,
	[reason_code] [int] NULL,
	[tnbordernum] [varchar](100) NULL,
	[peergrouplevel] [int] NULL,
	[trankey] [int] IDENTITY(1,1) NOT NULL,
	[Material] [numeric](16, 9) NULL,
	[MaterialOverhead] [numeric](16, 9) NULL,
	[DirectLabor] [numeric](16, 9) NULL,
	[VariableOverhead] [numeric](16, 9) NULL,
	[Freight] [numeric](16, 9) NULL,
	[FixedOverhead] [numeric](16, 9) NULL,
	[zUOM] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FactPPB]

-- %%
/****** Object:  Table [dbo].[FactPPB]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FactPPB](
	[OrderId] [varchar](50) NULL,
	[OrderLineId] [int] NULL,
	[tnbordernum] [varchar](100) NULL,
	[peergrouplevel] [int] NULL,
	[customerkey] [int] NOT NULL,
	[productkey] [int] NOT NULL,
	[RQMKey] [int] NOT NULL,
	[datekey] [int] NOT NULL,
	[OrderSizeKey] [decimal](19, 8) NULL,
	[QuoteFlagKey] [int] NOT NULL,
	[PeerPrice] [decimal](19, 8) NULL,
	[ExtendedPeerPrice] [decimal](19, 8) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[factquoteheaders]

-- %%
/****** Object:  Table [dbo].[factquoteheaders]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[factquoteheaders](
	[quotenumber] [numeric](16, 9) NOT NULL,
	[quoteddollars] [numeric](38, 9) NULL,
	[quotedquantity] [bigint] NULL,
	[SoldDollars] [numeric](38, 9) NULL,
	[soldquantity] [bigint] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FactQuotes]

-- %%
/****** Object:  Table [dbo].[FactQuotes]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FactQuotes](
	[QuoteKey] [int] IDENTITY(1,1) NOT NULL,
	[QuoteNumber] [numeric](16, 9) NOT NULL,
	[LineNumber] [varchar](5) NOT NULL,
	[CustomerKey] [int] NULL,
	[ProductKey] [int] NULL,
	[CatalogNumber] [varchar](50) NULL,
	[RQMKey] [int] NULL,
	[DateKey] [numeric](18, 0) NULL,
	[PriceSource] [varchar](8) NOT NULL,
	[EffectiveDate] [datetime] NULL,
	[ExpirationDate] [datetime] NULL,
	[QuotedDollars] [numeric](16, 9) NULL,
	[QuotedQuantity] [int] NULL,
	[ExtCost] [numeric](16, 9) NULL,
	[UOM] [int] NOT NULL,
	[Discount] [numeric](16, 9) NULL,
	[BusinessUnit] [varchar](50) NULL,
	[QuoteType] [varchar](50) NULL,
	[LineWin] [varchar](8) NOT NULL,
	[QuoteWinKey] [int] NOT NULL,
	[WinStatus] [int] NOT NULL,
	[OrderSizeKey] [int] NOT NULL,
	[QuoteFlagKey] [int] NOT NULL,
	[SpaKey] [int] NOT NULL,
	[TimeUtilityKey] [int] NOT NULL,
	[WinKey] [int] NOT NULL,
	[GoldBookPrice] [numeric](27, 9) NULL,
	[NetPromoPrice] [numeric](28, 9) NULL,
	[LogID] [int] NOT NULL,
	[SPA] [int] NOT NULL,
	[SoldDollars] [numeric](16, 9) NULL,
	[SoldQty] [int] NULL,
	[pricematrix] [varchar](10) NOT NULL,
	[abcmatrix] [varchar](10) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FactWaterfall]

-- %%
/****** Object:  Table [dbo].[FactWaterfall]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FactWaterfall](
	[wfCode] [varchar](255) NULL,
	[CustomerKey] [int] NULL,
	[ProductKey] [int] NULL,
	[RQMKey] [int] NULL,
	[DateKey] [int] NULL,
	[OrderSizeKey] [int] NULL,
	[QuoteFlagKey] [int] NULL,
	[SpaKey] [int] NULL,
	[TimeUtilityKey] [int] NULL,
	[PriceSource] [varchar](20) NULL,
	[Amount] [decimal](19, 8) NULL,
	[UOM] [int] NULL,
	[PriceMatrix] [varchar](10) NULL,
	[ABCMatrix] [varchar](10) NULL,
	[BusinessUnit] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[logBatch]

-- %%
/****** Object:  Table [dbo].[logBatch]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[logBatch](
	[batchID] [int] IDENTITY(1,1) NOT NULL,
	[periodStartDate] [smalldatetime] NULL,
	[periodEndDate] [smalldatetime] NULL,
	[startTime] [datetime] NOT NULL,
	[endTime] [datetime] NULL,
	[activity] [nvarchar](50) NULL,
 CONSTRAINT [LOGBATCH_PK] PRIMARY KEY CLUSTERED 
(
	[batchID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[logErrorSeverity]

-- %%
/****** Object:  Table [dbo].[logErrorSeverity]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[logErrorSeverity](
	[errorFlag] [int] NOT NULL,
	[errorDesc] [nvarchar](50) NULL,
	[abortProcess] [nchar](1) NULL,
 CONSTRAINT [LOGERRORSEVERITY_PK] PRIMARY KEY CLUSTERED 
(
	[errorFlag] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[logSession]

-- %%
/****** Object:  Table [dbo].[logSession]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[logSession](
	[spID] [int] NOT NULL,
	[logLevel] [nvarchar](8) NULL,
	[section] [nvarchar](1000) NULL,
 CONSTRAINT [LOGSESSION_PK] PRIMARY KEY CLUSTERED 
(
	[spID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[logTable]

-- %%
/****** Object:  Table [dbo].[logTable]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[logTable](
	[logID] [int] IDENTITY(1,1) NOT NULL,
	[batchID] [int] NULL,
	[logLevel] [nvarchar](8) NULL,
	[processName] [nvarchar](50) NULL,
	[action] [nvarchar](8) NULL,
	[startTime] [datetime] NULL,
	[endTime] [datetime] NULL,
	[logText] [nvarchar](2048) NULL,
	[section] [nvarchar](1000) NULL,
	[tblName] [nvarchar](50) NULL,
	[colName] [nvarchar](50) NULL,
	[tableRowCount] [int] NULL,
	[insertCount] [int] NULL,
	[updateCount] [int] NULL,
	[rejectCount] [int] NULL,
	[deleteCount] [int] NULL,
	[errorFlag] [int] NULL,
	[number1] [numeric](19, 2) NULL,
	[number2] [numeric](19, 2) NULL,
	[number3] [numeric](19, 2) NULL,
	[reportLevel] [tinyint] NULL,
	[spID] [int] NULL,
 CONSTRAINT [LOGTABLE_PK] PRIMARY KEY CLUSTERED 
(
	[logID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MetaUtilDBPurge]

-- %%
/****** Object:  Table [dbo].[MetaUtilDBPurge]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MetaUtilDBPurge](
	[purgeFactTable] [varchar](255) NOT NULL,
	[datePart] [varchar](10) NOT NULL,
	[periodLen] [int] NOT NULL,
	[dateKeyColumn] [varchar](255) NOT NULL,
 CONSTRAINT [PK_METAUTILDBPURGE] PRIMARY KEY CLUSTERED 
(
	[purgeFactTable] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[o_DimProduct_Bucket]

-- %%
/****** Object:  Table [dbo].[o_DimProduct_Bucket]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[o_DimProduct_Bucket](
	[ProdLine] [varchar](3) NULL,
	[ProdGroup] [varchar](5) NULL,
	[PLBucket] [varchar](50) NULL,
	[PGBucket] [varchar](50) NULL,
	[NewBucket] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[pg_disc]

-- %%
/****** Object:  Table [dbo].[pg_disc]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[pg_disc](
	[txnmonth] [int] NULL,
	[bu] [varchar](100) NULL,
	[Region] [varchar](203) NULL,
	[SalesOffice] [varchar](203) NULL,
	[prodgroup] [varchar](100) NULL,
	[goldbookprice] [decimal](38, 8) NULL,
	[salesdollars] [decimal](38, 8) NULL,
	[txncount] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ppbfact]

-- %%
/****** Object:  Table [dbo].[ppbfact]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ppbfact](
	[trankey] [int] NOT NULL,
	[ProductLineBucket] [varchar](50) NULL,
	[ProductGroupBucket] [varchar](50) NULL,
	[ProductGroup] [varchar](100) NULL,
	[ProductVelocity] [varchar](50) NULL,
	[productkey] [varchar](50) NULL,
	[QuoteFlag] [varchar](50) NULL,
	[OrderSizeBucket] [varchar](20) NULL,
	[salesofficecode] [varchar](100) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ppboutput]

-- %%
/****** Object:  Table [dbo].[ppboutput]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ppboutput](
	[trankey] [int] NOT NULL,
	[mediandv] [numeric](38, 10) NULL,
	[peergrouplevel] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PPBRunResults]

-- %%
/****** Object:  Table [dbo].[PPBRunResults]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PPBRunResults](
	[RunId] [numeric](19, 0) NULL,
	[RunDate] [datetime] NULL,
	[SubRunId] [numeric](19, 0) NULL,
	[Status] [nvarchar](255) NULL,
	[ProductLineBucket] [nvarchar](255) NULL,
	[ProductGroupBucket] [nvarchar](255) NULL,
	[ProductGroup] [nvarchar](255) NULL,
	[ProductVelocity] [nvarchar](255) NULL,
	[productkey] [nvarchar](255) NULL,
	[QuoteFlag] [nvarchar](255) NULL,
	[OrderSizeBucket] [nvarchar](255) NULL,
	[SalesOfficeCode] [nvarchar](255) NULL,
	[MaxDV] [numeric](38, 10) NULL,
	[MedianDV] [numeric](38, 10) NULL,
	[MinDV] [numeric](38, 10) NULL,
	[Txns] [numeric](38, 10) NULL,
	[LogID] [int] NULL,
	[peergrouplevel] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[prodratio]

-- %%
/****** Object:  Table [dbo].[prodratio]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[prodratio](
	[customerkey] [int] NOT NULL,
	[coreprodkey] [varchar](203) NULL,
	[compprodkey] [varchar](203) NULL,
	[coredoll] [decimal](38, 8) NULL,
	[compdoll] [decimal](38, 8) NULL,
	[coreqty] [decimal](38, 8) NULL,
	[compqty] [decimal](38, 8) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sysdtslog90]

-- %%
/****** Object:  Table [dbo].[sysdtslog90]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sysdtslog90](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[event] [sysname] NOT NULL,
	[computer] [nvarchar](128) NOT NULL,
	[operator] [nvarchar](128) NOT NULL,
	[source] [nvarchar](1024) NOT NULL,
	[sourceid] [uniqueidentifier] NOT NULL,
	[executionid] [uniqueidentifier] NOT NULL,
	[starttime] [datetime] NOT NULL,
	[endtime] [datetime] NOT NULL,
	[datacode] [int] NOT NULL,
	[databytes] [image] NULL,
	[message] [nvarchar](2048) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__logBatch__activi__300424B4]

-- %%
ALTER TABLE [dbo].[logBatch] ADD  DEFAULT (N'ETL') FOR [activity]
GO

-- %% [markdown]
-- # [DF__logTable__startT__3C2B9B25]

-- %%
ALTER TABLE [dbo].[logTable] ADD  CONSTRAINT [DF__logTable__startT__3C2B9B25]  DEFAULT (getdate()) FOR [startTime]
GO

-- %% [markdown]
-- # [DF__logTable__insert__3D1FBF5E]

-- %%
ALTER TABLE [dbo].[logTable] ADD  CONSTRAINT [DF__logTable__insert__3D1FBF5E]  DEFAULT ((0)) FOR [insertCount]
GO

-- %% [markdown]
-- # [DF__logTable__update__3E13E397]

-- %%
ALTER TABLE [dbo].[logTable] ADD  CONSTRAINT [DF__logTable__update__3E13E397]  DEFAULT ((0)) FOR [updateCount]
GO

-- %% [markdown]
-- # [DF__logTable__reject__3F0807D0]

-- %%
ALTER TABLE [dbo].[logTable] ADD  CONSTRAINT [DF__logTable__reject__3F0807D0]  DEFAULT ((0)) FOR [rejectCount]
GO

-- %% [markdown]
-- # [DF__logTable__delete__3FFC2C09]

-- %%
ALTER TABLE [dbo].[logTable] ADD  CONSTRAINT [DF__logTable__delete__3FFC2C09]  DEFAULT ((0)) FOR [deleteCount]
GO

-- %% [markdown]
-- # [DF__logTable__report__40F05042]

-- %%
ALTER TABLE [dbo].[logTable] ADD  CONSTRAINT [DF__logTable__report__40F05042]  DEFAULT ((0)) FOR [reportLevel]
GO

-- %% [markdown]
-- # [dbo].[sp_dts_addlogentry]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_dts_addlogentry]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_dts_addlogentry]  @event sysname,  @computer nvarchar(128),  @operator nvarchar(128),  @source nvarchar(1024),  @sourceid uniqueidentifier,  @executionid uniqueidentifier,  @starttime datetime,  @endtime datetime,  @datacode int,  @databytes image,  @message nvarchar(2048)AS  INSERT INTO sysdtslog90 (      event,      computer,      operator,      source,      sourceid,      executionid,      starttime,      endtime,      datacode,      databytes,      message )  VALUES (      @event,      @computer,      @operator,      @source,      @sourceid,      @executionid,      @starttime,      @endtime,      @datacode,      @databytes,      @message )  RETURN 0
GO

-- %% [markdown]
-- # [dbo].[sp_logAndRethrowError]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_logAndRethrowError]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
-- Create the stored procedure to generate an error using 
-- RAISERROR. The original error is logged into logTable.

create procedure [dbo].[sp_logAndRethrowError] 
as 
begin 
    -- return if there is no error information to retrieve.
    if error_number() is null
        return;

    declare 
        @ErrorMessage    nvarchar(4000),
        @ErrorNumber     int,
        @ErrorSeverity   int,
        @ErrorState      int,
        @ErrorLine       int,
        @ErrorProcedure  nvarchar(200);


    -- Assign variables to error-handling functions that 
    select 
        @ErrorNumber = ERROR_NUMBER(),
        @ErrorSeverity = ERROR_SEVERITY(),
        @ErrorState = ERROR_STATE(),
        @ErrorLine = ERROR_LINE(),
        @ErrorProcedure = isnull(ERROR_PROCEDURE(), '-');


    -- Building the message string with original error information.
    set @ErrorMessage = N'Error Number ' + cast(@ErrorNumber AS nvarchar(50))+ ', ' +
                         'Error Line '   + cast(@ErrorLine AS nvarchar(50)) + ', ' +
                         'Error Message : ''' + error_message() + ''''
                       
                                 
    -- Logging the error information into logTable if it isn't logged yet
    if @ErrorState < 127 
        exec sp_logWrite @logLevel = 'FATAL', 
                         @processName = @ErrorProcedure, 
                         @logText = @ErrorMessage      


    -- Raising an error
    raiserror(
        @ErrorMessage, 
        @ErrorSeverity, 
        127 -- indicates that error is thrown mannualy 
    );
end
GO

-- %% [markdown]
-- # [dbo].[sp_logBatch]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_logBatch]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[sp_logBatch] (@action nvarchar(8), @activity nvarchar(50) = NULL) as

set nocount on
declare @recCount integer
-- Start
if @action = N'Start' begin
   insert logBatch (startTime, activity)
            values (getdate(), coalesce(@activity, N'ETL'))
end
else begin
  -- Stop
  if @action = N'Stop' begin
     update logBatch
        set endTime = getdate()
      where batchID = (select max(batchID) from logBatch where activity = coalesce(@activity, activity))
        
  end
  else begin
      -- error
      RAISERROR (N'Invalid Action parameter <%s> for sp_logBatch',
                  16, 1, @action)
      return(-2)
  end
end
GO

-- %% [markdown]
-- # [dbo].[sp_logBeginSection]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_logBeginSection]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
create procedure [dbo].[sp_logBeginSection] (@section nvarchar(1000)) as


set nocount on
SET TRANSACTION ISOLATION LEVEL READ UNCOMMITTED
declare @currentSection nvarchar(1000)
declare @separator nchar(1)
set @separator = N'.'
select @currentSection = section
  from logSession
 where spID = @@SPID
-- record not found hence initialize it
if @@ROWCOUNT = 0
  begin
    exec sp_logInitialize
    set @currentSection = NULL
  end
if @currentSection is NULL or len(@currentSection) = 0
 begin
   UPDATE logSession
     set section = @section
   where spID = @@SPID
 end
else
 begin
   UPDATE logSession
     set section = @currentSection + @separator + @section
   where spID = @@SPID
 end
GO

-- %% [markdown]
-- # [dbo].[sp_logEmail]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_logEmail]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
create procedure [dbo].[sp_logEmail] (@recipients nvarchar(1024) = NULL,
                               @message nvarchar(4000) = NULL,
                               @subject nvarchar(4000) = NULL,
                               @query nvarchar(4000) = NULL,
                               @attach_results nvarchar(10) = N'false') as

set nocount on

declare @dbname nvarchar(50)
declare @mailTo nvarchar(100)
declare @logEmailEnabled nvarchar(10)

-- get database
set @dbname = DB_NAME()

-- check if email enabled at client (default is YES)
set @logEmailEnabled = 'YES'
if @logEmailEnabled <> N'YES' begin
   return
end


if @recipients is NULL begin
  set @mailTo = 'email@domain.com'
 end
else
 begin
  set @mailTo = @recipients
 end
--print @mailTo


if @query is null begin
   exec master.dbo.xp_sendmail
     @recipients = @mailTo
    ,@message = @message
    ,@subject = @subject
    ,@no_output = N'false'
    ,@echo_error= N'false'
    ,@set_user=N'dbo'
    ,@dbuse = @dbname
    ,@width = 255
    ,@separator = N','
  end
ELSE
  begin
   if @attach_results = N'true' begin
      exec master.dbo.xp_sendmail
       @recipients = @mailTo
      ,@message = @message
      ,@subject = @subject
      ,@no_output = N'false'
      ,@echo_error= N'false'
      ,@set_user=N'dbo'
      ,@dbuse = @dbname
      ,@width = 255
      ,@separator = N','
      ,@query = @query
      ,@attach_results = N'true'
      ,@attachments = N'RunLogResults.csv'
    end
   else
    begin
      exec master.dbo.xp_sendmail
       @recipients = @mailTo
      ,@message = @message
      ,@subject = @subject
      ,@no_output = N'false'
      ,@echo_error= N'false'
      ,@set_user=N'dbo'
      ,@dbuse = @dbname
      ,@width = 255
      ,@separator = N' '
      ,@query = @query
    end
  end




/*
exec sp_logEmail @recipients = N'nilesh.lakhani@zilliant.com',
                 @subject = N'Lithonia Load Stages 1 thru 8 Completed Successfully',
                 @message = N'Results are attached in a csv file. Please import into Excel with comma as a separator.
',
                 @query =  N'
select * from logTable where batchID = (select max(batchID) from logbatch)'

exec sp_logEmail @subject = N'Lithonia Load Stages 1 thru 8 Completed Successfully',
                 @message = N'this is a test -------- >',
                 @query =  N'select * from logBatch where batchID = (select max(batchID) from logbatch)'

*/
GO

-- %% [markdown]
-- # [dbo].[sp_logEndSection]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_logEndSection]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
create procedure [dbo].[sp_logEndSection] (@section nvarchar(1000) = NULL) as

set nocount on
SET TRANSACTION ISOLATION LEVEL READ UNCOMMITTED
declare @currentSection nvarchar(1000)
declare @pos integer
-- if input is NULL then clear all sections
if @section is NULL
 begin
  UPDATE logSession
    set section = NULL
  where spID = @@SPID
  return
 end
select @currentSection = section 
 from logSession
where spID = @@SPID
set @pos = charindex(@section, @currentSection)
-- section not found, no action required
if @pos = 0 or @pos is NULL
  return
-- also remove 1 char separator '.'. If first one, then clear it.
if @pos = 1
  begin
   set @currentSection = NULL
  end
else
  begin
   set @currentSection = substring(@currentSection, 1, @pos - 2)
  end
UPDATE logSession
  set section = @currentSection
where spID = @@SPID
GO

-- %% [markdown]
-- # [dbo].[sp_logGetLevel]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_logGetLevel]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
create procedure [dbo].[sp_logGetLevel] (@logLevel nvarchar(8) OUTPUT) as


set nocount on
SET TRANSACTION ISOLATION LEVEL READ UNCOMMITTED
set @logLevel = NULL
select @logLevel = logLevel
  from logSession
 where spID = @@SPID
-- if not found, then it will return a NULL
if @@ROWCOUNT = 0 begin
   -- call initialize session
   exec sp_logInitialize
   select @logLevel = logLevel
     from logSession
    where spID = @@SPID
end
GO

-- %% [markdown]
-- # [dbo].[sp_logGetSection]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_logGetSection]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
create procedure [dbo].[sp_logGetSection] (@section nvarchar(1000) OUTPUT) as


set nocount on
SET TRANSACTION ISOLATION LEVEL READ UNCOMMITTED
set @section = NULL
select @section = section
  from logSession
 where spID = @@SPID
-- if not found, then it will return a NULL
GO

-- %% [markdown]
-- # [dbo].[sp_logInitialize]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_logInitialize]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
create procedure [dbo].[sp_logInitialize] (@type nvarchar(8) = N'session') as


set nocount on
SET TRANSACTION ISOLATION LEVEL READ UNCOMMITTED
declare @spID integer
declare @logLevel nvarchar(25)
-- logLevel (side effect is that if logLevel is not set-up in rep_olapParms
--           then it returns ERROR which is a valid logLevel)
--exec sp_getOlapParms N'logLevel', @logLevel OUTPUT

set @logLevel = 'INFO'
--print '@logLevel= ' + @logLevel
-- if initialize all then truncate table
if @type = N'all'
 truncate table logSession
-- clear section for current process
SELECT @spID = spID FROM logSession where spID = @@SPID
if @@ROWCOUNT = 0
  begin
    INSERT logSession (spID, logLevel, section)
               VALUES (@@SPID, @logLevel, NULL)
  end
else
  begin
    UPDATE logSession
      set logLevel = @logLevel,
          section = NULL
    where spID = @@SPID
  end
GO

-- %% [markdown]
-- # [dbo].[sp_logInsertData]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_logInsertData]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
create procedure [dbo].[sp_logInsertData] as

DECLARE @total int

/* check if logTables already initialized, then just a log msg */
SELECT @total = count(*) FROM logErrorSeverity

IF @total > 0 
BEGIN
   exec sp_logWrite @processName = N'sp_logInsertData',
                   @logText = N'Log Tables already initialized, skipping truncation to retain log.'
   RETURN
END

TRUNCATE TABLE logBatch
INSERT logBatch (startTime, EndTime)
         VALUES (getdate(), getdate())
-- logErrorSeverity
TRUNCATE TABLE logErrorSeverity
INSERT logErrorSeverity (errorFlag, errorDesc, abortProcess)
                 VALUES (-2,'-2 : Fatal Error','Y')
INSERT logErrorSeverity (errorFlag, errorDesc, abortProcess)
                 VALUES (-1,'-1 : Business Rule Violation','Y')
INSERT logErrorSeverity (errorFlag, errorDesc, abortProcess)
                 VALUES (0,'0 : Success','N')
INSERT logErrorSeverity (errorFlag, errorDesc, abortProcess)
                 VALUES (1,'1 : Warning','N')
INSERT logErrorSeverity (errorFlag, errorDesc, abortProcess)
                 VALUES (2,'2 : Information','N')
exec sp_logInitialize
TRUNCATE TABLE logTable
exec sp_logWrite @processName = N'sp_logInsertData',
                   @logText = N'Log Tables initialized'
GO

-- %% [markdown]
-- # [dbo].[sp_logPurge]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_logPurge]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
create procedure [dbo].[sp_logPurge] as


set nocount on
SET TRANSACTION ISOLATION LEVEL READ UNCOMMITTED
declare @strNoOfDays nvarchar(25)
declare @noOfDays integer
declare @msg nvarchar(80)
declare @deleteCount integer
set @strNoOfDays = 365
set @noOfDays = cast(@strNoOfDays as integer)
if @noOfDays is NULL
  return 0
delete from logTable
 where startTime < dateadd(day, -@noOfDays, getdate())
set @deleteCount = @@ROWCOUNT
if @deleteCount > 0
  begin
    --print cast(@deleteCount as nvarchar)
    set @msg = N'No of records deleted = ' + cast (@deleteCount as nvarchar) +
               N' for retention period = ' + @strNoOfDays  + N' days'
    exec sp_logWrite @processName=N'sp_logPurge',
                     @logText = @msg,
                     @deletecount = @deleteCount,
                     @logLevel = N'WARN'
  end
GO

-- %% [markdown]
-- # [dbo].[sp_logSetLevel]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_logSetLevel]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
create procedure [dbo].[sp_logSetLevel] (@logLevel nvarchar(8)) as

set nocount on
SET TRANSACTION ISOLATION LEVEL READ UNCOMMITTED
UPDATE logSession
   set logLevel = @logLevel
 where spID = @@SPID
if @@ROWCOUNT = 0
  begin
    RAISERROR (N'Error setting session logLevel in sp_logSetLevel, session = %d not found in logSession = %s',
              16, 1, @@SPID, @logLevel)
    return (1)
  end
-- if not found, then it will return a NULL
GO

-- %% [markdown]
-- # [dbo].[sp_logSeverityProcessing]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_logSeverityProcessing]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
create procedure [dbo].[sp_logSeverityProcessing] (@errorFlag integer,
                                            @processName nvarchar(50),
                                            @logText nvarchar(2048) = NULL) as

set nocount on
SET TRANSACTION ISOLATION LEVEL READ UNCOMMITTED
declare @abortProcess nchar(1)
declare @logID integer
declare @subject nvarchar(200)
-- validate severity error and abort if failure (less than zero)
if @errorFlag = 0
  return
select @abortProcess=abortProcess
 from logErrorSeverity
where errorFlag = @errorFlag and abortProcess = N'Y'
if @@ROWCOUNT = 0 begin
   return(0)
end
-- check if abort process required
select @logID = max(logID) from logTable where processName = @processName
if @logID is Null
  set @logID = -1
set @subject = N'***ZPRO Fatal error logged for processName = ' +
               @processName + N', logID = ' + cast(@logID as nvarchar)
exec sp_logEmail @subject = @subject,
                 @message = @logText
RAISERROR (N'Serious error found for processName = %s, error severity = %d in sp_logSeverityProcessing',
           16, 1, @processName, @errorFlag)
return(@errorFlag)
GO

-- %% [markdown]
-- # [dbo].[sp_logWrite]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_logWrite]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
create procedure [dbo].[sp_logWrite] (@logLevel nvarchar(8) = 'INFO',
                               @processName nvarchar(50) = NULL,
                               @logText nvarchar(2048) = NULL,
                               @action nvarchar(8) = 'LogInfo',
                               @tblName nvarchar(50) = NULL,
                               @colName nvarchar(50) = NULL,
                               @tableRowCount integer = 0,
                               @insertCount integer = 0,
                               @updateCount integer = 0,
                               @rejectCount integer = 0,
                               @deleteCount integer = 0,
                               @errorFlag integer = 0,
                               @number1 float = NULL,
                               @number2 float = NULL,
                               @number3 float = NULL,
                               @reportLevel tinyint = 0
                               ) as


set nocount on
SET TRANSACTION ISOLATION LEVEL READ UNCOMMITTED
declare @errorSeverityID integer
declare @batchID integer
declare @logID integer
declare @rowCount integer
declare @currTime datetime
declare @defaultLogLevel nvarchar(25)
declare @defaultLevelNo int
declare @currentLevelNo int
declare @allLogLevels nvarchar(40)
declare @section nvarchar(1000)
-- check @action
if @action not in (N'Start', N'Stop', N'LogInfo', N'sqlDebug') begin
   RAISERROR (N'action <%s> is invalid, correct code',
              16, 1, @action)
end
-- check logLevel, if not greater or equal to current default level, then return with no logging.
-- some fancy string manipulation to set the order
set @allLogLevels = N'OFFFATALERRORWARNINFODEBUGALL'
set @currentLevelNo = charindex(@logLevel, @allLogLevels)
if @currentLevelNo = 0 begin
   RAISERROR (N'sp_logWrite.logLevel <%s> is invalid, pass the correct level parameter',
              16, 1, @logLevel)
   return(1)
end
exec sp_logGetLevel @defaultLogLevel OUTPUT
if @defaultLogLevel = 'OFF' or @logLevel = 'OFF' begin
   return(0)
end
set @defaultLevelNo = charindex(@defaultLogLevel, @allLogLevels)
if @defaultLevelNo = 0 begin
   RAISERROR (N'logSession.logLevel <%s> is not set-up, set it up',
              16, 1, @defaultLogLevel)
   return(1)
end
-- check if logging level is > than default level
if @currentLevelNo > @defaultLevelNo begin
   return(0)
end
--
-- Stop Log - Must have Start record
if @action = N'Stop' begin
-- get record to be updated
  select @logID = max(logID)
  from logTable
  where processName = @processName and action = N'Start'
  if @logID is not null begin
  -- now update record
    UPDATE logTable
      set endTime = getdate(),
          action = @action,
          tblName = @tblName,
          colName = @colName,
          logText = @logText,
          tableRowCount = @tableRowCount,
          insertCount = @insertCount,
          updateCount = @updateCount,
          rejectCount = @rejectCount,
          deleteCount = @deleteCount,
          errorFlag = @errorFlag,
          number1 = @number1,
          number2 = @number2,
          number3 = @number3,
          reportLevel = @reportLevel
    where logID = @logID
    if @@ROWCOUNT = 0 begin
      RAISERROR (N'processName <%s> update failed in sp_logWrite',
                16, 1, @processName)
      return(-1)
    end
    -- check if abort required.
    exec sp_logSeverityProcessing @errorFlag = @errorFlag,
                                  @processName = @processName,
                                  @logText = @logText
    return 0
  end
  else begin
  RAISERROR (N'Expecting Log record to update for processName <%s>',
              16, 1, @processName)
  end
end
--
-- Start or LogInfo process
-- get batchID
select @batchID = max(batchID) from logBatch
-- get section
exec sp_logGetSection @section=@section OUTPUT
-- set time
if @action = N'Start' begin
   set @currTime = NULL
end
else begin
   set @currTime = getdate()
end
--write record to the table
insert INTO logTable
             (batchID, logLevel, processName, action, endTime,
              logText, section, tblName, colname, errorFlag,
              tableRowCount, insertCount, updateCount, rejectCount, deleteCount,
              number1, number2, number3, reportLevel, spID)
      VALUES (@batchID, @logLevel, @processName, @action, @currTime,
              @logText, @section, @tblName, @colName, @errorFlag,
              @tableRowCount, @insertCount, @updateCount, @rejectCount, @deleteCount,
              @number1, @number2, @number3, @reportLevel, @@SPID)
if @@ROWCOUNT = 0 begin
   RAISERROR (N'processName <%s> insert failed',
              16, 1, @processName)
   return(-1)
end
-- check if abort required
exec sp_logSeverityProcessing @errorFlag = @errorFlag,
                              @processName = @processName,
                              @logText = @logText
return 0
GO

-- %% [markdown]
-- # [dbo].[sp_sqlDebug]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_sqlDebug]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
create procedure [dbo].[sp_sqlDebug] (@sqlText nvarchar(2048),
                                   @processName nvarchar(50) = NULL) as

declare @logText nvarchar(2048)
declare @crlf nchar(2)
set @crlf = cast(char(13) as nchar(1))+cast(char(10) as nchar(1))
set @logText = replace(@sqlText,@crlf,' ')
exec sp_logWrite @action = N'sqlDebug'
                ,@logLevel = N'DEBUG'
                ,@processName = @processName
                ,@logText = @logText
/*
exec sp_sqlDebug N'test sql statement'
exec sp_sqlDebug @sqlText = N'test sql statement with processName', @processName = N'test'
*/
GO

-- %% [markdown]
-- # [dbo].[spr_addPurgeFactTable]

-- %%
/****** Object:  StoredProcedure [dbo].[spr_addPurgeFactTable]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
create procedure [dbo].[spr_addPurgeFactTable]
    @purgeFactTable varchar(255),
    @datePart       varchar(10),
    @periodLength   int,
    @dateKeyColumn  varchar(255) = NULL 
as
begin

    begin try
        if not exists (select * from MetaUtilDBPurge where purgeFactTable = @purgeFactTable)
        begin
            insert into MetaUtilDBPurge(purgeFactTable, datePart, periodLen, dateKeyColumn)
            values (@purgeFactTable, @datePart, @periodLength, coalesce(@dateKeyColumn, 'DateKey'))
        end
        else 
        begin
            update MetaUtilDBPurge
               set datePart      = @datePart,
                   periodLen     = @periodLength,
                   dateKeyColumn = coalesce(@dateKeyColumn, dateKeyColumn)
             where purgeFactTable = @purgeFactTable
        end
    end try
    begin catch
        exec sp_logAndRethrowError     
    end catch

end
GO

-- %% [markdown]
-- # [dbo].[spr_dimProcessingCustomers]

-- %%
/****** Object:  StoredProcedure [dbo].[spr_dimProcessingCustomers]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[spr_dimProcessingCustomers] as 
begin

    /*
    exec spr_dimProcessingCustomers

    select * from customers
    select * from DimCustomer
    select * from logTable where processName = 'spr_dimProcessingCustomers'
    truncate table logTable
    */

/*
Goals
1.	Insert customers from pricingstaging
2.	Get undefined customers from quotes
3.	Get undefined customers from orders
4.	Apply customer velocity
5.	Apply customer chain district key
6.	Apply customer chain key
7.	Update unknown dimension attributes
*/
    begin try
        declare @processName varchar(100)
        declare @tableName varchar(50)
        declare @stgTableRowCount int
        declare @dmRowCountBeforeProcessing int
        declare @dmFinalTableRowCount int
        declare @logID int
        declare @insertCount int
        declare @updateCount int
        declare @currentDate datetime
		declare @mediantop int
		declare @medianbottom int
		declare @uppertop int
		declare @upperbottom int
		declare @lowertop int
		declare @lowerbottom int
		declare @salesmedian numeric(38,16)
		declare @saleslower numeric(38,16)		
		declare @salesupper numeric(38,16)

        -- initialize parameters
        set @processName = 'spr_dimProcessingCustomers'
        set @tableName = 'DimCustomer'
        set @stgTableRowCount = (select count(Distributor_id) from pricingstaging..Customer)
        set @dmRowCountBeforeProcessing = (select count(customerKey) from DimCustomer)
        set @currentDate = getDate()

        /*
        Initialize the logs for this procedure
        EVERY STORED PROCEDURES SHOULD INCLUDE AT LEAST A START AND STOP LOG ENTRY
        */
        exec sp_logBeginSection @processName
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @number1 = @stgTableRowCount,
		        @number2 = @dmRowCountBeforeProcessing
        -- get the logid from the logTable for this process
        set @logID = (select max(logID) from logTable where processName = @processName)


        /*--------------------------------------------------------------------------------------------*/
        /*------1.	Insert customers from pricingstaging-----------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        /*
        First insert new records into the pricingstaging table where dimension records do not exist.
        This should be implemented for every dimenion being processed whether it is a type 1 or type 2 dimension.
        */
        exec sp_logBeginSection 'New Dimension Records'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName
        -- get the logid from the logTable for this process
        set @logID = (select max(logID) from logTable where processName = @processName)
		truncate table DimCustomer 
        insert into DimCustomer (
													CustomerNumber,--1
													CustName,--2
													CustChainCode, --3
													CustChainDescr, --4
													CustDistCode, --5
                                                    CustDistDesc, --6
													CustRegCode, --7
													CustRegDesc, --8
													SalesOfficeCode, --9
													SalesOfficeDesc, --10
													ParentCustomerNumber, --11
													BusinessUnitId, --12
													DomSalesOffice, --13
                                                    CustVelocity, --14
													RowIsCurrent, --15
													RowStartDate, --16
													RowEndDate, --17
													LogID,
													Source)--18
			select stg.Distributor_id,--1
					stg.Name,--2
					stg.Chain_id,--3
					stg.Chain_name,--4
					stg.District_id,--5
					stg.District_name,--6
					stg.Region_id,--7
					stg.Region_desc,--8
					stg.Sales_office_id,--9
					stg.Sales_office_desc,--10
					stg.Comp_sheet,--11
					stg.business_unit_id,--12
					-1, --stg.DomSalesOfficeBucket,--13
					-1, --stg.CustVelocity--14
					1,--15
					getdate(),--@currentDate,--16
					'12-31-2099',--17
					@logID,
					'Extract' --18
			from pricingstaging..Customer stg

        -- get the row count to include in the logging
        set @insertCount = @@rowcount

        /*
        Log the number of new records inserted into the dimension table
        */
        exec sp_logWrite @action = 'STOP',
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'New Dimension Records'
        		

        /*--------------------------------------------------------------------------------------------*/
        /*------2.	Get undefined customers from quotes-----------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/
        exec sp_logBeginSection 'Get undefined customers from quotes'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName,
		        @tblName = @tableName, 
		        @logText = @processName

		select  
		CUSTOMER_NUM	distributor_id,
		AGENT			sales_office_id,
		REGION			region_id,
		MKT_GROUP_ID	Business_unit_id,
		count(*) qty
		into #quotecustomer
		from pricingstaging.dbo.quotes
		group by 
		AGENT,
		REGION,
		MKT_GROUP_ID ,
		CUSTOMER_NUM
	
		delete from #quotecustomer 
		from #quotecustomer q
		join dimcustomer c
		on  c.customernumber	=q.distributor_id	
		AND	c.SalesOfficeCode	=q.sales_office_id
		AND	c.CustRegCode			=q.region_id	
		AND c.BusinessUnitId	=q.Business_unit_id

		insert into 
		DimCustomer
		(
		CustomerNumber,				
		SalesOfficeCode,
		CustRegCode,						
		BusinessUnitId,
		Source
		)
		SELECT
		distributor_id,				
		sales_office_id,
		region_id,						
		Business_unit_id,
		'Quotes'
		FROM
		#quotecustomer

        set @insertCount = @@rowcount

		UPDATE DimCustomerQuotes
		SET CustName = DimCustomerExtract.CustName
		FROM (SELECT * from DimCustomer where Source = 'Quotes') DimCustomerQuotes
		JOIN (SELECT * from DimCustomer where Source = 'Extract') DimCustomerExtract
		ON DimCustomerQuotes.CustomerNumber	= DimCustomerExtract.CustomerNumber				

		UPDATE DimCustomerQuotes
		SET CustRegDesc = DimCustomerExtract.CustRegDesc
		FROM (SELECT * from DimCustomer where Source = 'Quotes') DimCustomerQuotes
		JOIN (SELECT * from DimCustomer where Source = 'Extract') DimCustomerExtract
		ON DimCustomerQuotes.CustRegCode	= DimCustomerExtract.CustRegCode				

		UPDATE DimCustomerQuotes
		SET SalesOfficeDesc = DimCustomerExtract.SalesOfficeDesc
		FROM (SELECT * from DimCustomer where Source = 'Quotes') DimCustomerQuotes
		JOIN (SELECT * from DimCustomer where Source = 'Extract') DimCustomerExtract
		ON DimCustomerQuotes.SalesOfficeCode	= DimCustomerExtract.SalesOfficeCode				

        -- log the update
        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'Get undefined customers from quotes'

        /*--------------------------------------------------------------------------------------------*/
        /*------3.	Get undefined customers from orders-----------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/
        exec sp_logBeginSection 'Get undefined customers from orders'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName,
		        @tblName = @tableName, 
		        @logText = @processName

		select  
		distributor_id,
		convert(varchar(50),agent_office_id) sales_office_id,
		region_id,
		Business_unit_id,
		sum(ext_price) salesdollars
		into #quoteorder
		from pricingstaging.dbo.orders
		group by 
		region_id,
		agent_office_id,
		Business_unit_id,
		distributor_id

		delete from #quoteorder 
		from #quoteorder q
		join dimcustomer c
		on  c.customernumber	=q.distributor_id	
		AND	c.SalesOfficeCode	=q.sales_office_id
		AND	c.CustRegCode			=q.region_id	
		AND c.BusinessUnitId	=q.Business_unit_id

		insert into 
		DimCustomer
		(
		CustomerNumber,				
		SalesOfficeCode,
		CustRegCode,						
		BusinessUnitId,
		Source
		)
		SELECT
		distributor_id,				
		sales_office_id,
		region_id,						
		Business_unit_id,
		'Orders'
		FROM
		#quoteorder

        set @insertCount = @@rowcount

		UPDATE DimCustomerOrders
		SET CustName = DimCustomerExtract.CustName
		FROM (SELECT * from DimCustomer where Source = 'Orders') DimCustomerOrders
		JOIN (SELECT * from DimCustomer where Source = 'Extract') DimCustomerExtract
		ON DimCustomerOrders.CustomerNumber	= DimCustomerExtract.CustomerNumber				

		UPDATE DimCustomerOrders
		SET CustRegDesc = DimCustomerExtract.CustRegDesc
		FROM (SELECT * from DimCustomer where Source = 'Orders') DimCustomerOrders
		JOIN (SELECT * from DimCustomer where Source = 'Extract') DimCustomerExtract
		ON DimCustomerOrders.CustRegCode	= DimCustomerExtract.CustRegCode				

		UPDATE DimCustomerOrders
		SET SalesOfficeDesc = DimCustomerExtract.SalesOfficeDesc
		FROM (SELECT * from DimCustomer where Source = 'Orders') DimCustomerOrders
		JOIN (SELECT * from DimCustomer where Source = 'Extract') DimCustomerExtract
		ON DimCustomerOrders.SalesOfficeCode	= DimCustomerExtract.SalesOfficeCode	

        -- log the update
        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'Get undefined customers from orders'


        /*--------------------------------------------------------------------------------------------*/
        /*----------4. Apply customer velocity--------------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'Apply customer velocity'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName,
		        @tblName = @tableName, 
		        @logText = @processName
				
				set @currentDate = dateadd(dd,-365,(select max(invoice_date) from pricingstaging.dbo.orders))

				select 
				row_number() OVER(order by sum(ext_price)) rank, 
				distributor_id customerkey, 
				sum(ext_price) sales
				into #customervelocity
				from pricingstaging.dbo.orders
				where invoice_date < @currentDate
				and line_type = 'I'
				group by distributor_id

			
				set @medianbottom 
				= 	case	when @@rowcount % 2 = 1 then ((@@rowcount-1)/2 + 1)
					else 	(@@rowcount)/2 - 1 end
				
				set @mediantop 
				= 	case	when @@rowcount % 2 = 1 then ((@@rowcount-1)/2 + 1)
					else 	((@@rowcount)/2)  end

				if @mediantop = @medianbottom
					begin
							set @salesmedian = (select sales from #customervelocity where rank = @mediantop)
							set @salesupper = 
							case 
								when	@mediantop % 2 = 0
								then	(select sales from #customervelocity where rank = @mediantop/2)	
								else	(
										select sum(sales)/2 
										from #customervelocity 
										where rank in (((@mediantop - 1)/2),(((@mediantop - 1)/2) + 1))
										)
								end		
							set @saleslower = 
							case 
								when	@mediantop % 2 = 0
								then	(select sales from #customervelocity where rank = (3*@mediantop)/2)
								else	(
										select sum(sales)/2 
										from #customervelocity 
										where rank in (((3*(@mediantop - 1))/2),(((3*(@mediantop - 1))/2) + 1))
										)
								end		
					end
				else
							set @salesmedian = (select sum(sales)/2 from #customervelocity where rank in (@mediantop, @medianbottom))
							set @salesupper = 
							case 
								when	@mediantop % 2 = 0
								then	(select sales from #customervelocity where rank = (@mediantop+1)/2)
								else	(
										select sum(sales)/2 
										from #customervelocity 
										where rank in (((@mediantop)/2),(((@mediantop)/2) + 1))
										)
								end										
							set @saleslower =
 							case 
								when	@mediantop % 2 = 0
								then	(select sales from #customervelocity where rank = (3*(@mediantop+1))/2)
								else	(
										select sum(sales)/2 
										from #customervelocity 
										where rank in (((3*(@mediantop))/2),(((3*(@mediantop))/2) + 1))
										)
								end

			update dimcustomer
			set CustVelocity
			= CASE 
			WHEN	v.sales >= @salesupper							THEN	'High Discount' 
			WHEN	v.sales BETWEEN @salesmedian AND @salesupper	THEN	'Medium High Discount'
			WHEN	v.sales BETWEEN @saleslower AND @salesmedian	THEN	'Medium Low Discount'
			WHEN	v.sales <= @saleslower							THEN	'Low Discount'
			ELSE 'Unknown'
			END ,
			velocitykey = CASE 
			WHEN	v.sales >= @salesupper							THEN	1 
			WHEN	v.sales BETWEEN @salesmedian AND @salesupper	THEN	2
			WHEN	v.sales BETWEEN @saleslower AND @salesmedian	THEN	3
			WHEN	v.sales <= @saleslower							THEN	4
			ELSE 5
			END 
			from dimcustomer p
			left join #customervelocity v
			on p.customernumber =v.customerkey

		set @updateCount = @@rowcount

        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @updateCount = @updateCount
        exec sp_logEndSection 'Apply customer velocity'


        /*--------------------------------------------------------------------------------------------*/
        /*-------5. Apply customer chain district key-------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'Apply customer chain district key'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName,
		        @tblName = @tableName, 
		        @logText = @processName

		select CustDistCode, 0 as  chaindistrictkey 
		into #districts
		from dimcustomer 
		where isnumeric(CustDistCode) = 1 and CustDistCode is not null
		
		update #districts set chaindistrictkey = convert(int, CustDistCode) 

		update dimcustomer set chaindistrictkey = d.chaindistrictkey 
		from dimcustomer c
		join #districts  d
		on c.CustDistCode = d.CustDistCode 

		set @updateCount = @@rowcount
		set @uppertop = (select max(chaindistrictkey) from dimcustomer)


		select @uppertop + row_number() OVER (ORDER BY CustDistCode ) chaindistrictkey,  CustDistCode, count(*) qty
		into #alphadistkey
		from dimcustomer where chaindistrictkey is null and CustDistCode is not null
		group by CustDistCode

		set @upperbottom = @@rowcount


		update dimcustomer set chaindistrictkey = a.chaindistrictkey
		from dimcustomer c
		join #alphadistkey a on
		a.CustDistCode= c.CustDistCode
		
		set @updateCount = @updateCount  + @@rowcount

		update dimcustomer set chaindistrictkey = @upperbottom + @uppertop + 1
		where chaindistrictkey is null

		set @updateCount = @updateCount  + @@rowcount

		update dimcustomer set custdistcode = 
		CASE 
		when len(custdistcode) = 2 and isnumeric(custdistcode) = 1 then '00'+ custdistcode
		when len(custdistcode) = 3 and isnumeric(custdistcode) = 1 then '0'+ custdistcode
		END

        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @updateCount = @updateCount
        exec sp_logEndSection 'Apply customer chain district key'


        /*--------------------------------------------------------------------------------------------*/
        /*-------6. Apply customer chain key----------------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'Apply customer chain key'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName,
		        @tblName = @tableName, 
		        @logText = @processName


		select CustChainCode, 0 as  chainkey 
		into #chains
		from dimcustomer 
		where isnumeric(CustChainCode) = 1 and CustChainCode is not null
		
		update #chains set chainkey = convert(int, CustChainCode) 

		update dimcustomer set chainkey = d.chainkey 
		from dimcustomer c
		join #chains  d
		on c.CustChainCode = d.CustChainCode 

		set @updateCount = @@rowcount
		set @uppertop = (select max(chainkey) from dimcustomer)

		select @uppertop + row_number() OVER (ORDER BY CustChainCode ) chainkey,  CustChainCode, count(*) qty
		into #alphachainkey
		from dimcustomer where chainkey is null and CustChainCode is not null
		group by CustChainCode

		set @upperbottom = @@rowcount

		update dimcustomer set chainkey = a.chainkey
		from dimcustomer c
		join #alphachainkey a on
		a.CustChainCode= c.CustChainCode
		
		set @updateCount = @updateCount  + @@rowcount

		update dimcustomer set chainkey = @upperbottom + @uppertop + 1
		where chainkey is null

		set @updateCount = @updateCount  + @@rowcount

        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @updateCount = @updateCount
        exec sp_logEndSection 'Apply customer chain key'

        /*--------------------------------------------------------------------------------------------*/
        /*-------7.	Update unknown dimension attributes-----------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'Update unknown dimension attributes'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName,
		        @tblName = @tableName, 
		        @logText = @processName
		
		UPDATE DimCustomer
		SET
		CustomerNumber  				= isnull(CustomerNumber  	,'zUnknown - CustomerNumber'),
		CustName        				= isnull(CustName        	,'zUnknown - CustName'),
		CustChainCode   				= isnull(CustChainCode   	,'zUnknown - CustChainCode'),
		CustChainDescr  				= isnull(CustChainDescr  	,'zUnknown - CustChainDesc'),
		CustDistCode    				= isnull(CustDistCode    	,'zUnknown - CustDistCode'),
		CustDistDesc    				= isnull(CustDistDesc    	,'zUnknown - CustDistDesc'),
		CustRegCode     				= isnull(CustRegCode     	,'zUnknown - CustRegCode'),
		CustRegDesc     				= isnull(CustRegDesc     	,'zUnknown - CustRegDesc'),
		SalesOfficeCode 				= isnull(SalesOfficeCode 	,'zUnknown - SalesOfficeCode'),
		SalesOfficeDesc 				= isnull(SalesOfficeDesc 	,'zUnknown - SalesOfficeDesc'),
		ParentCustomerNumber			= isnull(ParentCustomerNumber,'zUnknown -ParentCustomer'),
		BusinessUnitId  				= isnull(BusinessUnitId  	,'zUnknown - BusinessUnitId'),
		DomSalesOfficeCode  			= isnull(DomSalesOfficeCode  ,'zUnknown -DomSalesOfficeCode'),
		RowIsCurrent    				= 1,
		RowStartDate    				= getdate(),
		RowEndDate      				= '12-31-2099'


        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @updateCount = @updateCount
        exec sp_logEndSection 'Update unknown dimension attributes'

        /*
        Finalize the logs for this procedure
        */
        set @dmFinalTableRowCount = (select count(customerKey) from DimCustomer)
        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @logText = 'Successful Run', 
		        @tblName = @tableName,
		        @tableRowCount = @dmFinalTableRowCount,
		        @number1 = @stgTableRowCount,
		        @number2 = @dmRowCountBeforeProcessing
        exec sp_logEndSection @processName

        exec sp_logEndSection @processName

    end try
    begin catch
        exec sp_logAndRethrowError     
    end catch
end
GO

-- %% [markdown]
-- # [dbo].[spr_dimProcessingDate]

-- %%
/****** Object:  StoredProcedure [dbo].[spr_dimProcessingDate]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[spr_dimProcessingDate]

as 
begin

/*`
exec spr_dimProcessingDate

select * from time
select * from DimDate
select * from logTable where processName = 'spr_dimProcessingDate'
truncate table logTable


History
==================
06/10/08	aminkin	added CompletedMonth to ETL
06/17/08	aminkin	cleanup for automation
*/

    begin try
        declare @processName varchar(100)
        declare @tableName varchar(50)
        declare @stgTableRowCount int
        declare @dmRowCountBeforeProcessing int
        declare @dmFinalTableRowCount int
        declare @logID int
        declare @insertCount int
        declare @updateCount int
        declare @currentDate datetime
		declare @startDate	datetime
		declare @endDate	datetime
        declare @dateScope   table(datetimestamp datetime primary key)

        -- initialize parameters
        set @processName = 'spr_dimProcessingDate'
        set @tableName = 'DimDate'
        set @stgTableRowCount = (select count(datekey) from DimDate)
        set @dmRowCountBeforeProcessing = (select count(dateKey) from DimDate)
        set @currentDate = getDate()
/*
1. Determine mindate/maxdate for orders
2. Determine mindate/maxdate for quote's effective date
3. populate table
*/
truncate table dimdate

insert into @datescope (datetimestamp)
select distinct x.invoice_date 
from 
(
select distinct invoice_date from pricingstaging.dbo.orders
where datediff(mm, invoice_date, getdate()) <= 38
union
select distinct effective_date from pricingstaging.dbo.quotes
where datediff(mm, effective_date, getdate()) <= 38
) x

--        -- initialize scope of dates table
--        if (@startDate is null) select @startDate = (select min(datetimestamp) from time)
--        if (@endDate  is null) select @endDate = (select max(datetimestamp) from time)
--        while (@startDate<=@endDate)
--        begin
--	        insert into @dateScope values(@startDate)
--	        set @startDate = @startDate +1
--        end


        /*
        Initialize the logs for this procedure
        EVERY STORED PROCEDURES SHOULD INCLUDE AT LEAST A START AND STOP LOG ENTRY
        */
        exec sp_logBeginSection @processName
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @number1 = @stgTableRowCount,
		        @number2 = @dmRowCountBeforeProcessing
        -- get the logid from the logTable for this process
        set @logID = (select max(logID) from logTable where processName = @processName)

        /*--------------------------------------------------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        /*
        First insert new records into the pricingstaging table where dimension records do not exist.
        This should be implemented for every dimenion being processed whether it is a type 1 or type 2 dimension.
        */
        exec sp_logBeginSection 'New Date Dimension Records'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName
        -- get the logid from the logTable for this process
        set @logID = (select max(logID) from logTable where processName = @processName)
 insert into DimDate (	DateKey,
							        Date,
							        Year,
							        Quarter,
							        QuarterKey,
							        Month,
							        MonthKey,
							        Day,
							        DayKey,
							        isWeekend,
							        isHoliday,
									CompletedMonth)
        select convert(int, convert(varchar(10), stg.datetimestamp, 112)),
		        stg.datetimestamp,
		        datepart(yyyy,stg.datetimestamp),
		        'Q '+cast(datepart(q,stg.datetimestamp)as varchar(1))+' '+right(cast(datepart(yyyy,stg.datetimestamp) as varchar(4)),2),
		        convert(int, convert(varchar(4), datepart(yyyy,stg.datetimestamp)) + convert(varchar(2), datepart(qq,stg.datetimestamp))),
		        convert(varchar(4), stg.datetimestamp)+right(cast(datepart(yyyy,stg.datetimestamp) as varchar(4)),2),
		        substring(convert(varchar(10), stg.datetimestamp, 112), 1, 6),
		        convert(varchar(8),stg.datetimestamp,1),
		        datepart(d,stg.datetimestamp),
		        case datepart(dw,stg.datetimestamp) 
				        when 1 then 1
				        when 7 then 1
				        else 0
		        end,
		        0,
				CASE WHEN DATEPART(d,DATEADD(d,1,stg.datetimestamp)) = 1 THEN 1 ELSE 0 END
        from (select datetimestamp from @dateScope ) stg

        -- get the row count to include in the logging
        set @insertCount = @@rowcount

        /*
        Log the number of new records inserted into the dimension table
        */
        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'New Date Dimension Records'
        		

        /*--------------------------------------------------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/





        /*--------------------------------------------------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/


        /*
        Finalize the logs for this procedure
        */
        set @dmFinalTableRowCount = (select count(dateKey) from DimDate)
        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @logText = 'Successful Run', 
		        @tblName = @tableName,
		        @tableRowCount = @dmFinalTableRowCount,
		        @number1 = @stgTableRowCount,
		        @number2 = @dmRowCountBeforeProcessing
        exec sp_logEndSection @processName

        exec sp_logEndSection @processName

    end try
    begin catch
        exec sp_logAndRethrowError     
    end catch
end
GO

-- %% [markdown]
-- # [dbo].[spr_dimProcessingGoldBook]

-- %%
/****** Object:  StoredProcedure [dbo].[spr_dimProcessingGoldBook]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[spr_dimProcessingGoldBook]

as 
begin

/*`
exec spr_dimProcessingGoldBook

select * from time
select * from DimDate
select * from logTable where processName = 'spr_dimProcessingGoldBook'
truncate table logTable


History
==================
06/17/08	aminkin	Converted form Transact-SQL
*/

/*
Goals:
==========
1. Insert goldbook prices for items 
2. Update prices in calcgoldbook as having most recent status
3. Update keys for matches with DimProduct
4. Update dimproduct to reflect most recent CalcGoldBook UOM
*/
    begin try
        declare @processName varchar(100)
        declare @tableName varchar(50)
        declare @stgTableRowCount int
        declare @dmRowCountBeforeProcessing int
        declare @dmFinalTableRowCount int
        declare @logID int
        declare @insertCount int
        declare @updateCount int

        set @processName = 'spr_dimProcessingGoldBook'
        set @tableName = 'CalcGoldBook'
        set @stgTableRowCount = (select count(Catalog_Nbr) from pricingstaging..CalcGoldBook)
        set @dmRowCountBeforeProcessing = (select count(*) from CalcGoldBook)

        exec sp_logBeginSection @processName
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @number1 = @stgTableRowCount,
		        @number2 = @dmRowCountBeforeProcessing
        -- get the logid from the logTable for this process
        set @logID = (select max(logID) from logTable where processName = @processName)
        /*--------------------------------------------------------------------------------------------*/
        /*1. Insert goldbook prices for items----------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'New GoldBook Price Records'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @number1 = @stgTableRowCount,
		        @number2 = @dmRowCountBeforeProcessing

		SELECT
		DISTINCT
		Catalog_Nbr,								--				CatalogNumber, 
		Product_Line,								--				ProductLine, 
		Product_Group,								--				ProductGroup, 
		EffectiveDate = getdate()	,								--				EffectiveDate, 
		ExpirationDate = '1/1/2099',									--				, 
		PriceMatrix = MATRIX_CODE,								--				PriceMatrix, 
		ABCMatrix = ABC_CODE,									--				ABCMatrix, 
		ExtPrice = Price,										--				ExtPrice, 
		UOM = CASE										--				UOM , 
		WHEN UNIT_OF_MEASURE LIKE '%M%' THEN 1000
		WHEN UNIT_OF_MEASURE LIKE '%C%' THEN 100
		ELSE 1 END,
		LogID = 300,--@logID	,									--				LogID, 
		zUOM = 0,
		-1 as productkey,
		unitgoldbookprice = Price /										--				unitgoldbookprice,
		CASE										 
		WHEN UNIT_OF_MEASURE LIKE '%M%' THEN 1000
		WHEN UNIT_OF_MEASURE LIKE '%C%' THEN 100
		ELSE 1 END,
		LatestPrice = 2	
		into #goldbook										--				LatestPrice
		from
			pricingstaging.dbo.calcgoldbook gb
			where gb.catalog_nbr is not null

			delete from #goldbook
			from #goldbook gb
			join calcgoldbook cgb
			on
			gb.Catalog_Nbr	=	cgb.CatalogNumber AND	
			gb.Product_Line	=		cgb.ProductLine AND 
			gb.Product_Group =	cgb.ProductGroup AND 
			gb.PriceMatrix	=		cgb.PriceMatrix AND 
			gb.ABCMatrix		=		cgb.ABCMatrix AND 
			gb.ExtPrice		=		cgb.ExtPrice
			

		UPDATE #goldbook
		set productkey = isnull(p.productkey,-1)					--				productkey
		from #goldbook gb
		left join dimproduct p
		on rtrim(ltrim(p.Catalognumber)) = rtrim(ltrim(gb.Catalog_Nbr))

		INSERT INTO calcGoldBook select * from #goldbook

		set @insertcount = @@rowcount
        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'New GoldBook Price Records'
        		

        /*--------------------------------------------------------------------------------------------*/
        /*2. Update prices in calcgoldbook as having most recent status-------------------------------*/
        /*--------------------------------------------------------------------------------------------*/
        exec sp_logBeginSection 'Deprecated GoldBook Price Records'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName

		UPDATE old
		SET 
			old.expirationdate = getdate(),
			old.LatestPrice = 0
		FROM CALCGOLDBOOK old
		JOIN CALCGOLDBOOK new
		ON rtrim(ltrim(old.Catalognumber)) = rtrim(ltrim(new.Catalognumber))
		where old.LatestPrice = 1
		and	  new.LatestPrice = 2

		set @insertcount = @@rowcount

        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'Deprecated GoldBook Price Records'

        /*--------------------------------------------------------------------------------------------*/
        /*3. Update  keys for matches with DimProduct-------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/
                exec sp_logBeginSection 'GoldBook Prices with New Keys'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName
		UPDATE CALCGOLDBOOK
		SET productkey = NULL

		UPDATE CALCGOLDBOOK
		SET productkey = isnull(p.productkey,-1)
		FROM CalcGoldBook gb
		left join dimproduct p
		on rtrim(ltrim(p.Catalognumber)) = rtrim(ltrim(gb.Catalognumber))
		--where LatestPrice <> 2

		set @insertcount = @@rowcount


        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'GoldBook Prices with New Keys'

		UPDATE CALCGOLDBOOK SET LatestPrice = 1 where LatestPrice = 2

        /*--------------------------------------------------------------------------------------------*/
        /*4. Update dimproduct to reflect most recent CalcGoldBookprices------------------------------*/
        /*--------------------------------------------------------------------------------------------*/


		exec sp_logBeginSection 'Updated Products with GoldBook UOM'
				exec sp_logWrite @action = 'START', 
						@logLevel = 'INFO', 
						@processName = @processName, 
						@tblName = @tableName,
						@logText = @processName

		UPDATE DimProduct
		SET 
			gbuom= isnull(gb.uom,1),
			gbunitprice= isnull(gb.unitgoldbookprice,0)
		FROM dimproduct p
		left join calcgoldbook gb
		on rtrim(ltrim(p.Catalognumber)) = rtrim(ltrim(gb.Catalognumber))
		set @insertcount = @@rowcount

        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'Updated Products with GoldBook UOM'
        /*
        Finalize the logs for this procedure
        */
        set @dmFinalTableRowCount = (select count(*) from CalcGoldBook)
        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @logText = 'Successful Run', 
		        @tblName = @tableName,
		        @tableRowCount = @dmFinalTableRowCount,
		        @number1 = @stgTableRowCount,
		        @number2 = @dmRowCountBeforeProcessing
        exec sp_logEndSection @processName

    end try
    begin catch
        exec sp_logAndRethrowError     
    end catch
end
GO

-- %% [markdown]
-- # [dbo].[spr_dimProcessingProducts]

-- %%
/****** Object:  StoredProcedure [dbo].[spr_dimProcessingProducts]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[spr_dimProcessingProducts]

as  
begin


/*`
exec spr_dimProcessingProducts

select * from products
select * from DimProduct
select * from logTable where processName = 'spr_dimProcessingProducts'
truncate table logTable
*/
    begin try
        declare @processName varchar(100)
        declare @tableName varchar(50)
        declare @stgTableRowCount int
        declare @dmRowCountBeforeProcessing int
        declare @dmFinalTableRowCount int
		declare @wheremadekey int
        declare @logID int
        declare @insertCount int
        declare @updateCount int
        declare @currentDate datetime

        -- initialize parameters
        set @processName = 'spr_dimProcessingProducts'
        set @tableName = 'DimProduct'
        set @stgTableRowCount = (select count(Catalog_number) from pricingstaging..Products)
        set @dmRowCountBeforeProcessing = (select count(productKey) from DimProduct)
        set @currentDate = getDate()
/*
Goals:
1. Insert products from pricingstaging
2. Get undefined products from quotes
3. Get undefined products from orders
4. Apply Catalog Number velocity
5. Apply prodgroup and prodline velocity
6. Add keys for wheremade sorts
7. Insert unknown dimensions
8. Update unknown dimension attributes
*/

        /*
        Initialize the logs for this procedure
        EVERY STORED PROCEDURES SHOULD INCLUDE AT LEAST A START AND STOP LOG ENTRY
        */
        exec sp_logBeginSection @processName
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @number1 = @stgTableRowCount,
		        @number2 = @dmRowCountBeforeProcessing
        -- get the logid from the logTable for this process
        set @logID = (select max(logID) from logTable where processName = @processName)


        /*--------------------------------------------------------------------------------------------*/
        /*--------------1. Insert products from pricingstaging-----------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        /*
        First insert new records into the pricingstaging table where dimension records do not exist.
        This should be implemented for every dimenion being processed whether it is a type 1 or type 2 dimension.
        */
        exec sp_logBeginSection 'New Product Dimension Records'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName
        -- get the logid from the logTable for this process
        set @logID = (select max(logID) from logTable where processName = @processName)

		truncate table DimProduct 

		insert into DimProduct (
		Catalognumber,				--Catalog_number, 
		ProdCatalogDesc,			--part_desc, 
		MarketPlanningGroup,		--management_group_code, 
		MarketPlanningGroupDesc,	--MarketPlanningGroupDesc, 
		ProdAssociation,			--productassociation, 
		ProdAssociationDesc,		--ProdAssociationDesc, 
		prodline,					--product_line_id, 
		prodlinedesc,				--prod_line_desc, 
		prodgroup,					--product_group_id, 
		prodgroupdesc,				--prod_group_desc, 
		ProductStatus,				--ProductStatus, 
		ProductPriority,			--product_priority, 
		Replacement_cat,			--Replacement_cat, 
		where_made_id,				--where_made_id, 
		Material,					--Material, 
		Freight,					--Freight, 
		Material_Overhead,			--Material_Overhead, 
		Direct_Labor,				--Direct_Labor, 
		Variable_Overhead,			--Variable_Overhead, 
		Fixed_Overhead,				--Fixed_Overhead, 
		productnew,					--new_product, 
		productvelocity,			--productvelocity, 
		pgvelocitykey,				--pgvelocitykey, 
		plvelocitykey,				--plvelocitykey, 
		ProductLineBucket,			--ProductLineBucket, 
		ProductGroupBucket,			--ProductGroupBucket, 
		velocitykey,				--velocitykey				
		LogID,
		Source
		)--19
		select  stg.Catalog_number, 
				stg.part_desc, 
				stg.management_group_code, 
				stg.MarketPlanningGroupDesc, 
				stg.productassociation, 
				stg.ProdAssociationDesc, 
				stg.product_line_id, 
				stg.prod_line_desc, 
				stg.product_group_id, 
				stg.prod_group_desc, 
				stg.ProductStatus, 
				stg.product_priority, 
				stg.Replacement_cat, 
				stg.where_made_id, 
				stg.Material, 
				stg.Freight, 
				stg.Material_Overhead, 
				stg.Direct_Labor, 
				stg.Variable_Overhead, 
				stg.Fixed_Overhead, 
				stg.new_product, 
				'Unknown' productvelocity, 
				1	AS pgvelocitykey, 
				1	AS plvelocitykey, 
				'Unknown' ProductLineBucket, 
				'Unknown' ProductGroupBucket,
				1	AS velocitykey, --stg.ProductGroupBucket,--14
				@LogID,
				'Extract'

		from pricingstaging.dbo.Products stg

        set @insertCount = @@rowcount

        /*
        Log the number of new records inserted into the dimension table
        */
        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'New Product Dimension Records'


        /*--------------------------------------------------------------------------------------------*/
        /*-------------2. Get undefined products from quotes------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'New Product Dimension Records from Quotes'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName


		select distinct PRODUCT_ID into #quoteproduct from pricingstaging..Quotes

		delete from #quoteproduct 
		from #quoteproduct q
		join dimproduct p
		on  q.PRODUCT_ID = p.prodline

		delete from #quoteproduct 
		from #quoteproduct q
		join dimproduct p
		on  q.PRODUCT_ID = p.prodgroup

		delete from #quoteproduct 
		from #quoteproduct q
		join dimproduct p
		on  q.PRODUCT_ID = p.catalognumber

		insert into 
		DimProduct 
		(
		Catalognumber,				--Catalog_number, 
		Source
		)
		SELECT
		PRODUCT_ID,
		'Quotes'
		FROM
		#quoteproduct

        set @insertCount = @@rowcount

        /*
        Log the number of new records inserted into the dimension table
        */
        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'New Product Dimension Records from Quotes'

        /*--------------------------------------------------------------------------------------------*/
        /*-------------3. Get undefined products from orders------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'New Product Dimension Records from Orders'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName

		select distinct Catalog_num into #orderproduct from pricingstaging..Orders

		delete from #orderproduct 
		from #orderproduct q
		join dimproduct p

		on  q.Catalog_num = p.prodline
		delete from #orderproduct 
		from #orderproduct q
		join dimproduct p
		on  q.Catalog_num = p.prodgroup

		delete from #orderproduct 
		from #orderproduct q
		join dimproduct p
		on  q.Catalog_num = p.catalognumber

		insert into 
		DimProduct 
		(
		Catalognumber,				--Catalog_number, 
		Source
		)
		SELECT
		Catalog_num,
		'Orders'
		FROM
		#orderproduct

        set @insertCount = @@rowcount

        /*
        Log the number of new records inserted into the dimension table
        */
        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'New Product Dimension Records from Orders'


        /*--------------------------------------------------------------------------------------------*/
        /*-------------4. Apply Catalog Number velocity------------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'Update Catalog Number Velocity'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName

		/*UPDATE PRODUCT VELOCITY */
		select 
		SUM(f.Ext_Price) as SalesDollars, 
		p.CatalogNumber into #ProdRevenue 
		FROM pricingstaging..Orders f, dimproduct p 
		WHERE f.catalog_num = p.catalognumber
		group by p.CatalogNumber

		UPDATE DimProduct
		SET 
		ProductVelocity = 
			CASE 
				WHEN f.SalesDollars >= 0 AND f.SalesDollars < 21722.13 THEN 'Low'-- Slow (low revenue) product
				WHEN f.SalesDollars >= 21722.13 AND f.SalesDollars < 153450.72 THEN 'Medium' -- Med-Low (Med Low revenue) Product
				WHEN f.SalesDollars >= 153450.72 AND f.SalesDollars < 1398615.59 THEN 'High' --- Med-Fast(Medium high revenue) product
				WHEN f.SalesDollars >= 1398615.59 THEN 'X High'  --Fast (high revenue) product
				ELSE 'zUnknown' END,
		velocitykey =
			CASE 
				WHEN f.SalesDollars >= 0 AND f.SalesDollars < 21722.13 THEN 4 -- Slow (low revenue) product
				WHEN f.SalesDollars >= 21722.13 AND f.SalesDollars < 153450.72 THEN 3 -- Med-Low (Med Low revenue) Product
				WHEN f.SalesDollars >= 153450.72 AND f.SalesDollars < 1398615.59 THEN 2 --- Med-Fast(Medium high revenue) product
				WHEN f.SalesDollars >= 1398615.59 THEN 1  --Fast (high revenue) product
				ELSE 5 END
		FROM DimProduct p
		RIGHT JOIN #ProdRevenue f 
		on f.CatalogNumber = p.CatalogNumber

        set @insertCount = @@rowcount

        /*
        Log the number of new records inserted into the dimension table
        */
        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'Update Catalog Number Velocity'


        /*--------------------------------------------------------------------------------------------*/
        /*-------------5. Apply prodgroup and prodline velocity---------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'Update Product Group and Product Line Velocity'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName
	
		UPDATE DimProduct 
		SET 
			ProductLineBucket = 
			CASE	o.PLBucket
			WHEN	'H'		THEN 'High Discount'		
			WHEN	'MH'	THEN 'Medium High Discount'	
			WHEN	'ML'	THEN 'Medium Low Discount'	
			WHEN	'L'		THEN 'Low Discount'			
			ELSE	'Unknown'	END,
			plvelocitykey =
			CASE	o.PLBucket
			WHEN	'H'		THEN 1
			WHEN	'MH'	THEN 2
			WHEN	'ML'	THEN 3
			WHEN	'L'		THEN 4
			ELSE	5						END,
			prodgroupdv	= isnull(o.NewBucket, 'Unknown prodgroupdv'),
			ProductGroupBucket = 
			CASE o.PGBucket
			WHEN	'High'		THEN 'High Discount'		
			WHEN	'Medium'	THEN 'Medium Discount'	
			WHEN	'Low'		THEN 'Low Discount'		
			ELSE	'Unknown'	END,
			pgvelocitykey =
			CASE o.PGBucket
			WHEN	'High'		THEN 1
			WHEN	'Medium'	THEN 2
			WHEN	'Low'		THEN 3
			ELSE	4  END
		FROM DimProduct p 
		LEFT JOIN o_DimProduct_Bucket o
		ON p.prodline = o.prodline

        set @insertCount = @@rowcount

        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'Update Product Group and Product Line Velocity'



        /*--------------------------------------------------------------------------------------------*/
        /*-------------6. Add keys for wheremade sorts------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'Update Where Made ID Sort'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName
	
				update dimproduct 
				set 
				wheremadekey = convert (int,where_made_id)
				where isnumeric(where_made_id) = 1 and where_made_id is not null
				
				set @insertCount = @@rowcount

				set @wheremadekey = (select max(wheremadekey) from dimproduct)

				update dimproduct set wheremadekey = @wheremadekey
				where wheremadekey is null


				set @insertCount = @insertCount + @@rowcount

        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'Update Where Made ID Sort'

        /*--------------------------------------------------------------------------------------------*/
        /*-------------7. Insert Default Dimension Member-----------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'Insert Default Dimension Member'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName

		SET IDENTITY_INSERT dimproduct ON

		insert into dimproduct
		(
		productkey, 
		Catalognumber, 
		ProdCatalogDesc, 
		MarketPlanningGroup, 
		MarketPlanningGroupDesc, 
		ProdAssociation, 
		ProdAssociationDesc, 
		prodline, 
		prodlinedesc, 
		prodgroup, 
		prodgroupdesc, 
		ProductStatus, 
		ProductPriority, 
		Replacement_cat, 
		where_made_id, 
		Material, 
		Freight, 
		Material_Overhead, 
		Direct_Labor, 
		Variable_Overhead, 
		Fixed_Overhead, 
		productnew, 
		productvelocity, 
		pgvelocitykey, 
		plvelocitykey, 
		ProductLineBucket, 
		ProductGroupBucket, 
		velocitykey, 
		prodgroupdv
		)
		values
		(
		-1,--productkey, 
		'zUnknown Catalognumber',	--Catalognumber, 
		'zUnknown ProdCatalogDesc',	--ProdCatalogDesc, 
		'zUnknown MktPlanGroup',	--MarketPlanningGroup, 
		'zUnknown MktPlanGroupDes',	--MarketPlanningGroupDesc, 
		'zUnknown ProdAssoc',	--ProdAssociation, 
		'zUnknown ProdAssocDesc',	--ProdAssociationDesc, 
		'zUnknown prodline',	--prodline, 
		'zUnknown prodlinedesc',	--prodlinedesc, 
		'zUnknown prodgroup',	--prodgroup, 
		'zUnknown prodgroupdesc',	--prodgroupdesc, 
		'zUnknown',	--ProductStatus, 
		'zUnknown',	--ProductPriority, 
		'zUnknown Replacement_cat',	--Replacement_cat, 
		'zUnknown Where Made',	--where_made_id, 
		0.0,	--Material, 
		0.0,	--Freight, 
		0.0,	--Material_Overhead, 
		0.0,	--Direct_Labor, 
		0.0,	--Variable_Overhead, 
		0.0,	--Fixed_Overhead, 
		'zUnknown',	--productnew, 
		'zUnknown',	--productvelocity, 
		4,	--pgvelocitykey, 
		5,	--plvelocitykey, 
		'zUnknown',	--ProductLineBucket, 
		'zUnknown',	--ProductGroupBucket, 
		5,	--velocitykey, 
		'zUnknown prodgroupdv'	--prodgroupdv
		)
		set @insertCount = @@rowcount

		SET IDENTITY_INSERT dimproduct OFF

        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'Insert Default Dimension Member'


        /*--------------------------------------------------------------------------------------------*/
        /*-------------8. Update unknown dimension attributes-----------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'Update unknown dimension attributes'
        exec sp_logWrite @action = 'START', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName
		UPDATE DimProduct
		SET
				Catalognumber			= ISNULL(Catalognumber			, 'zUnknown Catalognumber'),	--Catalognumber, 
				ProdCatalogDesc			= ISNULL(ProdCatalogDesc			, 'zUnknown ProdCatalogDesc'),	--ProdCatalogDesc, 
				MarketPlanningGroup		= ISNULL(MarketPlanningGroup		, 'zUnknown MktPlanGroup'),	--MarketPlanningGroup, 
				MarketPlanningGroupDesc	= ISNULL(MarketPlanningGroupDesc	, 'zUnknown MktPlanGroupDes'),	--MarketPlanningGroupDesc, 
				ProdAssociation			= ISNULL(ProdAssociation			, 'zUnknown ProdAssoc'),	--ProdAssociation, 
				ProdAssociationDesc		= ISNULL(ProdAssociationDesc		, 'zUnknown ProdAssocDesc'),	--ProdAssociationDesc, 
				prodline				= ISNULL(prodline				, 'zUnknown prodline'),	--prodline, 
				prodlinedesc			= ISNULL(prodlinedesc			, 'zUnknown prodlinedesc'),	--prodlinedesc, 
				prodgroup				= ISNULL(prodgroup				, 'zUnknown prodgroup'),	--prodgroup, 
				prodgroupdesc			= ISNULL(prodgroupdesc			, 'zUnknown prodgroupdesc'),	--prodgroupdesc, 
				ProductStatus			= ISNULL(ProductStatus			, 'zUnknown'),	--ProductStatus, 
				ProductPriority			= ISNULL(ProductPriority			, 'zUnknown'),	--ProductPriority, 
				Replacement_cat			= ISNULL(Replacement_cat			, 'zUnknown Replacement_cat'),	--Replacement_cat, 
				where_made_id			= ISNULL(where_made_id			, 'zUnknown Where Made'),	--where_made_id, 
				Material				= ISNULL(Material				, 0.0),	--Material, 
				Freight					= ISNULL(Freight				, 0.0),	--Freight, 
				Material_Overhead		= ISNULL(Material_Overhead		, 0.0),	--Material_Overhead, 
				Direct_Labor			= ISNULL(Direct_Labor			, 0.0),	--Direct_Labor, 
				Variable_Overhead		= ISNULL(Variable_Overhead		, 0.0),	--Variable_Overhead, 
				Fixed_Overhead			= ISNULL(Fixed_Overhead			, 0.0),	--Fixed_Overhead, 
				productnew				= ISNULL(productnew				, 'zUnknown'),	--productnew, 
				productvelocity			= ISNULL(productvelocity			, 'zUnknown'),	--productvelocity, 
				pgvelocitykey			= ISNULL(pgvelocitykey			, 4),	--pgvelocitykey, 
				plvelocitykey			= ISNULL(plvelocitykey			, 5),	--plvelocitykey, 
				ProductLineBucket		= ISNULL(ProductLineBucket		, 'zUnknown'),	--ProductLineBucket, 
				ProductGroupBucket		= ISNULL(ProductGroupBucket		, 'zUnknown'),	--ProductGroupBucket, 
				velocitykey				= ISNULL(velocitykey				, 5),	--velocitykey, 
				prodgroupdv				= ISNULL(prodgroupdv				,'zUnknown prodgroupdv')	--prodgroupdv

		set @insertCount = @@rowcount

        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'Update unknown dimension attributes'


        /*--------------------------------------------------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/
		select @dmFinalTableRowCount = (select count(productKey) from DimProduct)
        /*
        Finalize the logs for this procedure
        */
        set @dmFinalTableRowCount = (select count(productKey) from DimProduct)
        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @logText = 'Successful Run', 
		        @tblName = @tableName,
		        @tableRowCount = @dmFinalTableRowCount,
		        @number1 = @stgTableRowCount,
		        @number2 = @dmRowCountBeforeProcessing
        exec sp_logEndSection @processName

    end try
    begin catch
        exec sp_logAndRethrowError     
    end catch
end
GO

-- %% [markdown]
-- # [dbo].[spr_dimProcessingScoreCards]

-- %%
/****** Object:  StoredProcedure [dbo].[spr_dimProcessingScoreCards]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[spr_dimProcessingScoreCards]
	@startDate	datetime = NULL,
	@endDate	datetime = NULL
as 
begin

/*`
exec spr_dimProcessingDate

select * from time
select * from DimDate
select * from logTable where processName = 'spr_dimProcessingDate'
truncate table logTable


History
==================
06/10/08	aminkin	Initial Creation
*/




--1.	 Add additional ETL
--a.	Add five columns to DImProduct for calculations: . available for each product.  
--b.	Apply Median_DV from PPBRunResults  where possible navigating tree as outlined before
--c.	Go to transactions to find average mediandv where value not found in PPBRun Results
/*
SL	Friendly Name				PGL DimProductDV	DimproductKey		PBRunResultsKey
===============================================================================================
1	Productlinebucket			8	ProdLine_DV		ProductLineBucket	ProductLineBucket
2	new_productgroupbucket		7	ProdGrpVel_DV	prodgroupdv			ProductGroupBucket
3	prodgroup					6	ProdGrp_DV		prodgroup			ProductGroup
4	new_prodvelocity			5	ProdVel_DV		productvelocity		ProductVelocity
5	productid (catalognumber)	4	CatNum_DV		Catalognumber		productkey
*/

--alter table dimproduct add CatNum_DV numeric (16,9)
--alter table dimproduct add ProdGrp_DV numeric (16,9)
--alter table dimproduct add ProdGrpVel_DV numeric (16,9)
--alter table dimproduct add ProdLine_DV numeric (16,9)
--alter table dimproduct add ProdVel_DV numeric (16,9)
--select avg(mediandv) from ppbrunresults
--0.5119158449
/*
For scorecard:
Product Line Search only peergrouplevel =8 in PPBRunResults looking for a match to get mediandv.  
Product Group Search peergrouplevel 6-8 (one query per level, staring with 6) in PPBRunResults until you find a match to get mediandv
Catalog Number Search peergrouplevel 3-8 (one query per level, staring with 3) in PPBRunResults until you find a match to get mediandv
*/
update dimproduct set 
ProdLine_DV		= null
,ProdGrpVel_DV	= null
,ProdGrp_DV		= null
,ProdVel_DV		= null
,CatNum_DV		= null

select avg(((goldbookprice * (1-peerprice))- salesdollars)/salesdollars)
from factorders f
where f.quantity > 0 and f.salesdollars > 0 and f.spakey =1
--0.271791

Update dimproduct set CatNum_DV =P.mediandv
from dimproduct R
join 
ppbrunresults P
ON	P.ProductLineBucket		= R.ProductLineBucket		
AND	P.ProductGroupBucket	= R.prodgroupdv		
AND	P.ProductGroup			= R.prodgroup		
AND	P.ProductVelocity		= R.productvelocity	
AND	P.productkey			= R.Catalognumber	
WHERE CatNum_DV IS NULL
AND peergrouplevel = 4

Update dimproduct set CatNum_DV =P.mediandv
from dimproduct R
join 
ppbrunresults P
ON	P.ProductLineBucket		= R.ProductLineBucket		
AND	P.ProductGroupBucket	= R.prodgroupdv		
AND	P.ProductGroup			= R.prodgroup		
AND	P.ProductVelocity		= R.productvelocity	
--AND	P.productkey			= R.Catalognumber	
WHERE CatNum_DV IS NULL
AND peergrouplevel = 5

Update dimproduct set CatNum_DV =P.mediandv
from dimproduct R
join 
ppbrunresults P
ON	P.ProductLineBucket		= R.ProductLineBucket		
AND	P.ProductGroupBucket	= R.prodgroupdv		
AND	P.ProductGroup			= R.prodgroup		
--AND	P.ProductVelocity		= R.productvelocity	
--AND	P.productkey			= R.Catalognumber	
WHERE CatNum_DV IS NULL
AND peergrouplevel = 6

Update dimproduct set CatNum_DV =P.mediandv
from dimproduct R
join 
ppbrunresults P
ON	P.ProductLineBucket		= R.ProductLineBucket		
AND	P.ProductGroupBucket	= R.prodgroupdv		
--AND	P.ProductGroup			= R.prodgroup		
--AND	P.ProductVelocity		= R.productvelocity	
--AND	P.productkey			= R.Catalognumber	
WHERE CatNum_DV IS NULL
AND peergrouplevel = 7

Update dimproduct set CatNum_DV =P.mediandv
from dimproduct R
join 
ppbrunresults P
ON	P.ProductLineBucket		= R.ProductLineBucket		
WHERE CatNum_DV IS NULL
AND peergrouplevel = 8

select count(*) from dimproduct where CatNum_DV is null

drop table prodkeydv

select f.productkey, avg(((goldbookprice * (1-peerprice))- salesdollars)/salesdollars) peerprice
into prodkeydv
from dimproduct p
join factorders f
on f.productkey = p.productkey
where p.CatNum_DV is null
and f.quantity > 0 and f.salesdollars > 0 and spakey =1  and goldbookprice > 0
group by f.productkey

update dimproduct set CatNum_DV = f.peerprice
from dimproduct p
join prodkeydv f
on f.productkey = p.productkey
where CatNum_DV is null

update dimproduct 
set CatNum_DV  = 0.271791
where CatNum_DV is null or CatNum_DV = 0

select avg(CatNum_DV) from dimproduct 
/*
============================================================================
PRODUCT VELOCITY
============================================================================
*/

Update dimproduct set ProdVel_DV =P.mediandv
from dimproduct R
join 
ppbrunresults P
ON	P.ProductLineBucket		= R.ProductLineBucket		
AND	P.ProductGroupBucket	= R.prodgroupdv		
AND	P.ProductGroup			= R.prodgroup		
AND	P.ProductVelocity		= R.productvelocity	
WHERE ProdVel_DV IS NULL
AND peergrouplevel = 5

Update dimproduct set ProdVel_DV =P.mediandv
from dimproduct R
join 
ppbrunresults P
ON	P.ProductLineBucket		= R.ProductLineBucket		
AND	P.ProductGroupBucket	= R.prodgroupdv		
AND	P.ProductGroup			= R.prodgroup		
WHERE ProdVel_DV IS NULL
AND peergrouplevel = 6

Update dimproduct set ProdVel_DV =P.mediandv
from dimproduct R
join 
ppbrunresults P
ON	P.ProductLineBucket		= R.ProductLineBucket		
AND	P.ProductGroupBucket	= R.prodgroupdv			
WHERE ProdVel_DV IS NULL
AND peergrouplevel = 7

Update dimproduct set ProdVel_DV =P.mediandv
from dimproduct R
join 
ppbrunresults P
ON	P.ProductLineBucket		= R.ProductLineBucket			
WHERE ProdVel_DV IS NULL
AND peergrouplevel = 8

select count(*) from dimproduct where ProdVel_DV is null
--13755

drop table prodvelokeydv
select p.productvelocity, avg(((goldbookprice * (1-peerprice))- salesdollars)/salesdollars) peerprice
into prodvelokeydv
from dimproduct p
join factorders f
on f.productkey = p.productkey
where p.ProdVel_DV is null
and f.quantity > 0 and f.salesdollars > 0 and spakey =1 and goldbookprice > 0
group by p.productvelocity

update dimproduct set ProdVel_DV = f.peerprice
from dimproduct p
join prodvelokeydv f
on f.productvelocity = p.productvelocity
where ProdVel_DV is null or ProdVel_DV = 0

update dimproduct 
set ProdVel_DV  = 0.271791
where ProdVel_DV is null or ProdVel_DV = 0

/*
============================================================================
PRODUCT GROUP ProdGrp_DV, ProdGrpVel_DV, ProdLine_DV
============================================================================
*/

Update dimproduct set ProdGrp_DV =P.mediandv
from dimproduct R
join 
ppbrunresults P
ON	P.ProductLineBucket		= R.ProductLineBucket		
AND	P.ProductGroupBucket	= R.prodgroupdv		
AND	P.ProductGroup			= R.prodgroup			
WHERE ProdGrp_DV IS NULL
AND peergrouplevel = 6

Update dimproduct set ProdGrp_DV =P.mediandv
from dimproduct R
join 
ppbrunresults P
ON	P.ProductLineBucket		= R.ProductLineBucket		
AND	P.ProductGroupBucket	= R.prodgroupdv		
WHERE ProdGrp_DV IS NULL
AND peergrouplevel = 7

Update dimproduct set ProdGrp_DV =P.mediandv
from dimproduct R
join 
ppbrunresults P
ON	P.ProductLineBucket		= R.ProductLineBucket		
WHERE ProdGrp_DV IS NULL
AND peergrouplevel = 8

--select count(*) from dimproduct where ProdGrp_DV is null
--13755

drop table prodgrpkeydv

select p.prodgroup, avg(((goldbookprice * (1-peerprice))- salesdollars)/salesdollars) peerprice
into prodgrpkeydv
from dimproduct p
join factorders f
on f.productkey = p.productkey
where p.ProdGrp_DV is null
and f.quantity > 0 and f.salesdollars > 0 and spakey =1  and goldbookprice > 0
group by p.prodgroup

update dimproduct set ProdGrp_DV = f.peerprice
from dimproduct p
join prodgrpkeydv f
on f.prodgroup = p.prodgroup
where ProdGrp_DV is null or ProdGrp_DV = 0

update dimproduct 
set ProdGrp_DV  = 0.271791
where ProdGrp_DV is null or ProdGrp_DV = 0


/*
============================================================================
PRODUCT GROUP BUCKET ProdGrpVel_DV, ProdLine_DV
============================================================================
*/

Update dimproduct set ProdGrpVel_DV =P.mediandv
from dimproduct R
join 
ppbrunresults P
ON	P.ProductLineBucket		= R.ProductLineBucket		
AND	P.ProductGroupBucket	= R.prodgroupdv		
WHERE ProdGrpVel_DV IS NULL
AND peergrouplevel = 7

Update dimproduct set ProdGrpVel_DV =P.mediandv
from dimproduct R
join 
ppbrunresults P
ON	P.ProductLineBucket		= R.ProductLineBucket		
WHERE ProdGrpVel_DV IS NULL
AND peergrouplevel = 8

select count(*) from dimproduct where ProdGrpVel_DV is null
--13755
drop table prodgrplvlkeydv

select p.prodgroupdv, avg(((goldbookprice * (1-peerprice))- salesdollars)/salesdollars) peerprice
into prodgrplvlkeydv
from dimproduct p
join factorders f
on f.productkey = p.productkey
where p.ProdGrpVel_DV is null
and f.quantity > 0 and f.salesdollars > 0 and spakey =1  and goldbookprice > 0
group by p.prodgroupdv

update dimproduct set ProdGrpVel_DV = f.peerprice
from dimproduct p
join prodgrplvlkeydv f
on f.prodgroupdv = p.prodgroupdv
where ProdGrpVel_DV is null or ProdGrpVel_DV = 0

update dimproduct 
set ProdGrpVel_DV  = 0.271791
where ProdGrpVel_DV is null or ProdGrpVel_DV = 0

/*
============================================================================
PRODUCT LINE ProdLine_DV
============================================================================
*/

Update dimproduct set ProdLine_DV =P.mediandv
from dimproduct R
join 
ppbrunresults P
ON	P.ProductLineBucket		= R.ProductLineBucket			
WHERE ProdLine_DV IS NULL
AND peergrouplevel = 8

--select count(*) from dimproduct where ProdLine_DV is null
--13755
drop table prodlinekeydv

select p.ProductLineBucket, avg(((goldbookprice * (1-peerprice))- salesdollars)/salesdollars) peerprice
into prodlinekeydv
from dimproduct p
join factorders f
on f.productkey = p.productkey
where p.ProdLine_DV is null
and f.quantity > 0 and f.salesdollars > 0 and spakey =1  and goldbookprice > 0
group by p.ProductLineBucket

update dimproduct set ProdLine_DV = f.peerprice
from dimproduct p
join prodlinekeydv f
on f.ProductLineBucket = p.ProductLineBucket
where ProdLine_DV is null or ProdLine_DV = 0
--sp_who
update dimproduct 
set ProdLine_DV  = 0.271791
where ProdLine_DV is null or ProdLine_DV = 0

select 
avg(CatNum_DV),
avg(ProdVel_DV),
/*,*/
avg(ProdGrp_DV)
,
avg(ProdGrpVel_DV)
,avg(ProdLine_DV)

from dimproduct



IF  EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[cn_disc]') AND type in (N'U'))
drop table cn_disc

IF  EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[pl_disc]') AND type in (N'U'))
drop table pl_disc

IF  EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[pg_disc]') AND type in (N'U'))
drop table pg_disc

select 
convert(int,round(datekey/100,0,1)) txnmonth, 
s.BusinessUnitId bu,
s.CustRegCode + ' - '+ s.CustRegDesc Region,
s.salesofficecode + ' - '+s.SalesOfficedesc SalesOffice,  
p.prodline, 
sum(f.goldbookprice) goldbookprice , 
sum(f.salesdollars) salesdollars,
count(*) txncount
into pl_disc
from factorders f
join dimproduct p
on 
p.productkey = f.productkey
join dimcustomer s
on 
f.customerkey = s.customerkey
where salesdollars > 0  and goldbookprice > 0
group by 
convert(int,round(datekey/100,0,1)), 
s.BusinessUnitId,
s.CustRegCode + ' - '+ s.CustRegDesc,
s.salesofficecode + ' - '+s.SalesOfficedesc , 
p.prodline
--having count(*) >= 20


select 
convert(int,round(datekey/100,0,1)) txnmonth, 
s.BusinessUnitId bu,
s.CustRegCode + ' - '+ s.CustRegDesc Region,
s.salesofficecode + ' - '+s.SalesOfficedesc SalesOffice,  
p.prodgroup, 
sum(f.goldbookprice) goldbookprice , 
sum(f.salesdollars) salesdollars,
count(*) txncount
into pg_disc
from factorders f
join dimproduct p
on 
p.productkey = f.productkey
join dimcustomer s
on 
f.customerkey = s.customerkey
where salesdollars > 0  and goldbookprice > 0
group by 
convert(int,round(datekey/100,0,1)), 
s.BusinessUnitId ,
s.CustRegCode + ' - '+ s.CustRegDesc ,
s.salesofficecode + ' - '+s.SalesOfficedesc , 
p.prodgroup
--having count(*) >= 20

select 
convert(int,round(datekey/100,0,1)) txnmonth, 
s.BusinessUnitId bu,
s.CustRegCode + ' - '+ s.CustRegDesc region,
s.salesofficecode + ' - '+s.SalesOfficedesc SalesOffice,  
p.catalognumber, 
sum(f.goldbookprice) goldbookprice , 
sum(f.salesdollars) salesdollars,
count(*) txncount
into cn_disc
from factorders f
join dimproduct p
on 
p.productkey = f.productkey
join dimcustomer s
on 
f.customerkey = s.customerkey
where salesdollars > 0  and goldbookprice > 0
group by 
convert(int,round(datekey/100,0,1)), 
s.BusinessUnitId,
s.CustRegCode + ' - '+ s.CustRegDesc,
s.salesofficecode + ' - '+s.salesofficedesc, 
p.catalognumber

end
GO

-- %% [markdown]
-- # [dbo].[spr_factPostProcessing]

-- %%
/****** Object:  StoredProcedure [dbo].[spr_factPostProcessing]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[spr_factPostProcessing] as 
begin


/*
exec spr_factPostProcessing

select * from FactOrders

select top 1 * from orders
select top 1 * from FactOrders
select top 1 * from DimProduct
select top 1 * from DimCustomer
select top 1 * from DimRQM
select top 1 * from DimDate
select top 1 * from DimCurrency


select * from logTable where processName = 'spr_factPostProcessing'
truncate table logTable
*/

/*
History
==================
06/10/2008	aminkin		Initial creation
*/
/*
Goals

1. Update Quote Cost information
2. Update Win/Loss information
3. Build QuoteHeaders infrastructure
4. Create DimBusinessUnit dimension
5. Calculate GB Prices

*/

   begin try
        declare @processName varchar(100)
        declare @tableName varchar(50)
        declare @stgTableRowCount int
        declare @dmRowCountBeforeProcessing int
        declare @dmFinalTableRowCount int
        declare @logID int
        declare @insertCount int
        declare @updateCount int
        declare @currentDate datetime

        -- initialize parameters
        set @processName = 'spr_factPostProcessing'
        set @tableName = 'FactOrders'
        set @stgTableRowCount = (select count(Invoice_id) from pricingstaging.dbo.orders)
        set @dmRowCountBeforeProcessing = (select count(OrderKey) from FactOrders)
        set @currentDate = getDate()

        exec sp_logBeginSection @processName
        exec sp_logWrite @action = 'START', 
                @logLevel = 'INFO', 
                @processName = @processName, 
                @tblName = @tableName,
                @logText = @processName,
                @number1 = @stgTableRowCount,
                @number2 = @dmRowCountBeforeProcessing
        -- get the logid from the logTable for this process
        set @logID = (select max(logID) from logTable where processName = @processName)
 
/*
        /*--------------------------------------------------------------------------------------------*/
        /*--------------1. Update Quote Cost information----------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'Update Quote Cost information'
        exec sp_logWrite @action = 'START', 
                @logLevel = 'INFO', 
                @processName = @processName, 
                @tblName = @tableName,
                @logText = @processName
				

				declare @maxdate datetime
				declare @maxkey int
				
				set @maxdate = (select max([date]) from DimDate where datepart(dayofyear,[Date]) = 1)
				set @maxdate = dateadd(yy,-1,@maxdate)
				set @maxkey = (select datekey from dimdate where [Date] = @maxdate)

				select productkey, convert(numeric (16,9), 0.0) ext_cost, count(*) qty
				into #quotecosts
				from factquotes
				group by productkey

				select productkey , 
				avg(ExtCost/quantity) zunit_cost
				into #ordercostsold
				from factorders
				where datekey <  @maxkey
				and spakey =1 and salesdollars >0 and quantity > 0 and extcost >0
				group by productkey

				update #quotecosts
				set ext_cost
				= p.zunit_cost
				from #quotecosts q
				join #ordercostsold p
				on p.productkey = q.productkey
				where ext_cost = 0.0

				Update factquotes
				set extcost = uom*extcost
				from factquotes f
				join #quotecosts q
				on q.productkey = f.productkey



        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'Update Quote Cost information'
*/
        /*--------------------------------------------------------------------------------------------*/
        /*--------------2. Update Win/Loss information------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/
/*
        exec sp_logBeginSection 'Update Win/Loss information'
        exec sp_logWrite @action = 'START', 
                @logLevel = 'INFO', 
                @processName = @processName, 
                @tblName = @tableName,
                @logText = @processName

				declare @openkey int 
				declare @opendate datetime
				set @openkey = (select max(datekey) from factorders)
				set @opendate = (select [date] from dimdate where datekey = @openkey)

			IF  NOT EXISTS (SELECT * FROM sys.indexes WHERE object_id = OBJECT_ID(N'[dbo].[FactOrders]') 
			AND name = N'ix_quotelinewin')
				CREATE NONCLUSTERED INDEX [ix_quotelinewin] ON [dbo].[FactOrders] 
				(
					[QuoteNumber] ASC,
					[OrderLineId] ASC
				)
				INCLUDE ( [SalesDollars],
				[Quantity]) WITH (SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, DROP_EXISTING = OFF, ONLINE = OFF) ON [PRIMARY]

				update factquotes set linenumber = 0
				where isnumeric(linenumber) <>1

				UPDATE FactQuotes
				SET LineWin = CASE WHEN f.QuoteNumber IS NOT NULL 
				AND f.ORDERLINEID IS NOT NULL 
				THEN 'Win'
				ELSE 'Loss' END ,
				SoldDollars = isnull(f.SalesDollars,0),
				SoldQty		= isnull(f.Quantity,0)
				FROM  
							  FactQuotes  q 
				JOIN 
				(
				SELECT 
				QuoteNumber,
				ORDERLINEID,
				sum(SalesDollars) SalesDollars,
				sum(Quantity) Quantity
				FROM FactOrders
				WHERE Quotenumber >0
				GROUP BY
				QuoteNumber,
				ORDERLINEID

				) f 
				on q.QuoteNumber = f.QuoteNumber 
				AND q.LineNumber = f.ORDERLINEID 
			
			SELECT DISTINCT QuoteNumber 
			INTO #Wins
			FROM factquotes
			WHERE LineWin = 'Win'
			
			UPDATE FactQuotes
			SET WinStatus 
			= CASE
			WHEN w.quotenumber is NULL THEN	0										--0 = Loss
			WHEN q.ExpirationDate <= @opendate and w.quotenumber is NOT NULL THEN 1	--1 = Win
			WHEN q.ExpirationDate > @opendate and w.quotenumber is NOT NULL THEN 2	--2 = Open
			ELSE 3 END
			From FactQuotes q
			RIGHT JOIN #Wins w
			ON w.quotenumber = q.quotenumber


        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'Update Win/Loss information'
*/
        /*--------------------------------------------------------------------------------------------*/
        /*--------------3. Build QuoteHeaders infrastructure-------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'Build QuoteHeaders infrastructure'
        exec sp_logWrite @action = 'START', 
                @logLevel = 'INFO', 
                @processName = @processName, 
                @tblName = @tableName,
                @logText = @processName

				IF  EXISTS 
				(SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[factquoteheaders]') 
				AND type in (N'U'))
				drop table factquoteheaders

				select 
				quotenumber, 
				sum(quoteddollars)		quoteddollars, 
				sum(convert(bigint,quotedquantity))		quotedquantity, 
				sum(SoldDollars)		SoldDollars , 
				sum(convert(bigint,soldqty))		soldquantity
				into
				factquoteheaders
				from factquotes
				group by quotenumber

        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'Build QuoteHeaders infrastructure'

        /*--------------------------------------------------------------------------------------------*/
        /*--------------4. Create DimBusinessUnit dimension-------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'Create DimBusinessUnit dimension'
        exec sp_logWrite @action = 'START', 
                @logLevel = 'INFO', 
                @processName = @processName, 
                @tblName = @tableName,
                @logText = @processName

				IF  EXISTS 
				(SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[dimbusinessunit]') 
				AND type in (N'U'))
				drop table dimbusinessunit

				select z.businessunit
				into dimbusinessunit
				from 
				(
				select distinct BusinessUnit
				from factorders
				union
				select distinct BusinessUnit
				from factquotes
				) z

        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'Build QuoteHeaders infrastructure'


        /*--------------------------------------------------------------------------------------------*/
        /*--------------5. Calculate GB Prices--------------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

        exec sp_logBeginSection 'Calculate GB Prices'
        exec sp_logWrite @action = 'START', 
                @logLevel = 'INFO', 
                @processName = @processName, 
                @tblName = @tableName,
                @logText = @processName
		/*
		1. Generate unitprices
		2. Update DimProducts with unit price
		3. Update recent quotes and orders
		4. Update historical quotes
		*/
		declare @orderuom bit
		declare @quoteuom bit
			
		Select productkey, UOM, avg(SalesDollars/Quantity) unit_price
		into #unitprices
		from factorders
		where salesdollars >0 and quantity > 0 and spakey = 1
		group by productkey, UOM

		Select 	productkey, avg(unit_price) unitprice
		into #uomranges
		from #unitprices
		group by productkey

		update dimproduct
		set unitprice = u.unitprice
		from dimproduct p
		join #uomranges u
		on p.productkey = u.productkey

		update factorders
		set goldbookprice = case when gb.unitgoldbookprice IS NULL then f.salesdollars
							else f.quantity * gb.unitgoldbookprice end
		from factorders f
		left join calcgoldbook gb
		on f.productkey = gb.productkey
		and gb.latestprice = 1
		where salesdollars >0 and quantity > 0 and spakey = 1

		update factquotes
		set goldbookprice = case when gb.unitgoldbookprice IS NULL then f.quoteddollars
							else f.quotedquantity * gb.unitgoldbookprice end
		from factquotes f
		left join calcgoldbook gb
		on f.productkey = gb.productkey
		and gb.latestprice = 1
		where quoteddollars >0 and quotedquantity > 0
		
		update factorders
		set goldbookprice = salesdollars 
		where salesdollars <=0 or quantity <= 0

		update factquotes
		set goldbookprice = quoteddollars 
		where quoteddollars <=0 or quotedquantity <= 0
		

        exec sp_logWrite @action = 'STOP', 
		        @logLevel = 'INFO', 
		        @processName = @processName, 
		        @tblName = @tableName,
		        @logText = @processName,
		        @insertCount = @insertCount
        exec sp_logEndSection 'Calculate GB Prices'




        set @dmFinalTableRowCount = (select count(orderKey) from FactOrders)
        exec sp_logWrite @action = 'STOP', 
                @logLevel = 'INFO', 
                @processName = @processName, 
                @logText = 'Successful Run', 
                @tblName = @tableName,
                @tableRowCount = @dmFinalTableRowCount,
                @insertCount = @insertCount,
                @number1 = @stgTableRowCount,
                @number2 = @dmRowCountBeforeProcessing
        exec sp_logEndSection @processName

    end try
    begin catch
        exec sp_logAndRethrowError     
    end catch
end
GO

-- %% [markdown]
-- # [dbo].[spr_factProcessingPriceIndex]

-- %%
/****** Object:  StoredProcedure [dbo].[spr_factProcessingPriceIndex]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[spr_factProcessingPriceIndex] as
begin


/*
exec spr_factProcessingPriceIndex

select * from FactOrders

select top 1 * from orders
select top 1 * from FactOrders
select top 1 * from DimProduct
select top 1 * from DimCustomer
select top 1 * from DimRQM
select top 1 * from DimDate
select top 1 * from DimCurrency


select * from logTable where processName = 'spr_factProcessingPriceIndex'
truncate table logTable
*/

/*
History
==================
06/10/2008	aminkin		Initial creation
*/

/*
Goals

1. Create indexes for PPB application
2. Create ppbfact table for joins
3. Initialize ppboutput table/populate peergrouplevel 1
4.-10. Populate ppboutput with peergrouplevels 2 - 8
11. Apply to factorders 
*/
    begin try


-- logging parameters
declare @processName varchar(100)
declare @tableName varchar(50)
declare @finalTableRowCount int
declare @logID int
declare @updateCount int
declare @insertCount int
-- initialize parameters
set @processName = 'spr_factProcessingPriceIndex'
set @tableName = 'FactOrders'


exec sp_logBeginSection @processName
exec sp_logWrite @action = 'START', 
	@logLevel = 'INFO', 
	@processName = @processName, 
	@tblName = @tableName,
	@logText = @processName


        /*--------------------------------------------------------------------------------------------*/
        /*------1. Create indexes for PPB application-------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Create indexes for PPB application'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

			IF  NOT EXISTS (SELECT * FROM sys.indexes WHERE object_id = OBJECT_ID(N'[dbo].[DimProduct]') 
			AND name = N'ix_Product_PPB')

			CREATE INDEX [ix_Product_PPB] ON [dbo].[DimProduct] ([productkey])
			INCLUDE ( [Catalognumber],[prodgroup],[productvelocity],[ProductLineBucket],[ProductGroupBucket]) 

			IF  NOT EXISTS (SELECT * FROM sys.indexes WHERE object_id = OBJECT_ID(N'[dbo].[FactOrders]') 
			AND name = N'ix_ppb')

			CREATE NONCLUSTERED INDEX [ix_ppb] ON [dbo].[FactOrders] 
			( [QuoteFlagKey], [OrderSizeKey],[ProductKey] ,[RQMKey] )
			INCLUDE ( [trankey]) 

			set @updateCount = @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Create indexes for PPB application'

        /*--------------------------------------------------------------------------------------------*/
        /*------2. Create ppbfact table for joins-------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Create ppbfact table for joins'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

			IF  EXISTS (SELECT * FROM sys.objects WHERE object_id 
			= OBJECT_ID(N'[dbo].[PPBFact]'))
			DROP TABLE PPBFact

			select 
			f.trankey,
			p.ProductLineBucket,
			p.prodgroupdv ProductGroupBucket, 
			p.ProdGroup ProductGroup, 
			p.ProductVelocity, 
			p.catalognumber productkey, 
			q.QuoteFlagDesc QuoteFlag, 
			o.OrderSize OrderSizeBucket,
			c.SalesOfficeAgentCode salesofficecode
			into ppbfact
			from factorders f
			inner join pricingdatamart.dbo.DimOrderSize o on f.OrderSizeKey = o.OrderSizeKey
			inner join pricingdatamart.dbo.DimQuoteFlag q on f.QuoteFlagKey = q.QuoteFlagKey
			inner join  pricingdatamart.dbo.DimProduct p on f.ProductKey = p.ProductKey
			inner join DimRQM c on f.RQMKey = c.RQMKey
			where 
			f.Quantity > 0
			and f.salesdollars > 0 
			and spakey = 1 

			set @insertcount= @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Create ppbfact table for joins'

        /*--------------------------------------------------------------------------------------------*/
        /*------3. Initialize ppboutput table/populate peergrouplevel 1------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Initialize ppboutput table/populate peergrouplevel 1'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

			IF  EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[PPBOutput]'))
			DROP TABLE PPBOutput

			SELECT 
			p.trankey,
			r.mediandv,
			r.peergrouplevel
			into ppboutput
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket			
			AND p.ProductGroupBucket		=	r.ProductGroupBucket		
			AND p.ProductGroup				=	r.ProductGroup				
			AND p.ProductVelocity			=	r.ProductVelocity			
			AND p.productkey				=	r.productkey				
			AND p.QuoteFlag					=	r.QuoteFlag					
			AND p.OrderSizeBucket			=	r.OrderSizeBucket			
			AND p.SalesOfficeCode			=	r.SalesOfficeCode			
			AND r.peergrouplevel = 1
			AND r.mediandv < .9

			delete
			from ppbfact 
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket			
			AND p.ProductGroupBucket		=	r.ProductGroupBucket		
			AND p.ProductGroup				=	r.ProductGroup				
			AND p.ProductVelocity			=	r.ProductVelocity			
			AND p.productkey				=	r.productkey				
			AND p.QuoteFlag					=	r.QuoteFlag					
			AND p.OrderSizeBucket			=	r.OrderSizeBucket			
			AND p.SalesOfficeCode			=	r.SalesOfficeCode			
			AND r.peergrouplevel = 1

			set @insertcount= @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Initialize ppboutput table/populate peergrouplevel 1'

        /*--------------------------------------------------------------------------------------------*/
        /*------4. Populate ppboutput with peergrouplevels 2 -----------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Populate ppboutput with peergrouplevels 2'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

			INSERT into ppboutput (trankey, peergrouplevel, mediandv)
			SELECT 
			p.trankey,
			r.peergrouplevel,
			r.mediandv
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket			
			AND p.ProductGroupBucket		=	r.ProductGroupBucket		
			AND p.ProductGroup				=	r.ProductGroup				
			AND p.ProductVelocity			=	r.ProductVelocity			
			AND p.productkey				=	r.productkey				
			AND p.QuoteFlag					=	r.QuoteFlag					
			AND p.OrderSizeBucket			=	r.OrderSizeBucket			
			AND r.peergrouplevel = 2
			AND r.mediandv < .9

			delete
			from ppbfact 
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket			
			AND p.ProductGroupBucket		=	r.ProductGroupBucket		
			AND p.ProductGroup				=	r.ProductGroup				
			AND p.ProductVelocity			=	r.ProductVelocity			
			AND p.productkey				=	r.productkey				
			AND p.QuoteFlag					=	r.QuoteFlag					
			AND p.OrderSizeBucket			=	r.OrderSizeBucket			
			AND r.peergrouplevel = 2

			set @insertcount= @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Populate ppboutput with peergrouplevels 2'

        /*--------------------------------------------------------------------------------------------*/
        /*------5. Populate ppboutput with peergrouplevels 3 -----------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Populate ppboutput with peergrouplevels 3'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

			INSERT into ppboutput (trankey, peergrouplevel, mediandv)
			SELECT 
			p.trankey,
			r.peergrouplevel,
			r.mediandv
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket			
			AND p.ProductGroupBucket		=	r.ProductGroupBucket		
			AND p.ProductGroup				=	r.ProductGroup				
			AND p.ProductVelocity			=	r.ProductVelocity			
			AND p.productkey				=	r.productkey				
			AND p.QuoteFlag					=	r.QuoteFlag					
			AND r.peergrouplevel = 3
			AND r.mediandv < .9

			delete
			from ppbfact 
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket
			AND p.ProductGroupBucket		=	r.ProductGroupBucket
			AND p.ProductGroup				=	r.ProductGroup
			AND p.ProductVelocity			=	r.ProductVelocity
			AND p.productkey				=	r.productkey
			AND p.QuoteFlag					=	r.QuoteFlag
			AND r.peergrouplevel = 3

			set @insertcount= @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Populate ppboutput with peergrouplevels 3'

        /*--------------------------------------------------------------------------------------------*/
        /*------6. Populate ppboutput with peergrouplevels 4 -----------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Populate ppboutput with peergrouplevels 4'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

			INSERT into ppboutput (trankey, peergrouplevel, mediandv)
			SELECT 
			p.trankey,
			r.peergrouplevel,
			r.mediandv
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket			
			AND p.ProductGroupBucket		=	r.ProductGroupBucket		
			AND p.ProductGroup				=	r.ProductGroup				
			AND p.ProductVelocity			=	r.ProductVelocity			
			AND p.productkey				=	r.productkey				
			AND r.peergrouplevel = 4
			AND r.mediandv < .9

			delete
			from ppbfact 
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket
			AND p.ProductGroupBucket		=	r.ProductGroupBucket
			AND p.ProductGroup				=	r.ProductGroup
			AND p.ProductVelocity			=	r.ProductVelocity
			AND p.productkey				=	r.productkey
			AND r.peergrouplevel = 4

			set @insertcount= @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Populate ppboutput with peergrouplevels 4'

        /*--------------------------------------------------------------------------------------------*/
        /*------7. Populate ppboutput with peergrouplevels 5 -----------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Populate ppboutput with peergrouplevels 5'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

			INSERT into ppboutput (trankey, peergrouplevel, mediandv)
			SELECT 
			p.trankey,
			r.peergrouplevel,
			r.mediandv
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket			
			AND p.ProductGroupBucket		=	r.ProductGroupBucket		
			AND p.ProductGroup				=	r.ProductGroup				
			AND p.ProductVelocity			=	r.ProductVelocity			
			AND r.peergrouplevel = 5
			AND r.mediandv < .9

			delete
			from ppbfact 
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket
			AND p.ProductGroupBucket		=	r.ProductGroupBucket
			AND p.ProductGroup				=	r.ProductGroup
			AND p.ProductVelocity			=	r.ProductVelocity
			AND r.peergrouplevel = 5

			set @insertcount= @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Populate ppboutput with peergrouplevels 5'

        /*--------------------------------------------------------------------------------------------*/
        /*------8. Populate ppboutput with peergrouplevels 6 -----------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Populate ppboutput with peergrouplevels 6'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

			INSERT into ppboutput (trankey, peergrouplevel, mediandv)
			SELECT 
			p.trankey,
			r.peergrouplevel,
			r.mediandv
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket			
			AND p.ProductGroupBucket		=	r.ProductGroupBucket		
			AND p.ProductGroup				=	r.ProductGroup				
			AND r.peergrouplevel = 6
			AND r.mediandv < .9

			delete
			from ppbfact 
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket
			AND p.ProductGroupBucket		=	r.ProductGroupBucket
			AND p.ProductGroup				=	r.ProductGroup
			AND r.peergrouplevel = 6

			set @insertcount= @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Populate ppboutput with peergrouplevels 6'

        /*--------------------------------------------------------------------------------------------*/
        /*------9. Populate ppboutput with peergrouplevels 7 -----------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Populate ppboutput with peergrouplevels 7'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

			INSERT into ppboutput (trankey, peergrouplevel, mediandv)
			SELECT 
			p.trankey,
			r.peergrouplevel,
			r.mediandv
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket			
			AND p.ProductGroupBucket		=	r.ProductGroupBucket		
			AND r.peergrouplevel = 7
			AND r.mediandv < .9

			delete
			from ppbfact 
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket
			AND p.ProductGroupBucket		=	r.ProductGroupBucket
			AND r.peergrouplevel = 7

			set @insertcount= @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Populate ppboutput with peergrouplevels 7'

        /*--------------------------------------------------------------------------------------------*/
        /*------10. Populate ppboutput with peergrouplevels 8 ----------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Populate ppboutput with peergrouplevels 7'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

			INSERT into ppboutput (trankey, peergrouplevel, mediandv)
			SELECT 
			p.trankey,
			r.peergrouplevel,
			r.mediandv
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket					
			AND r.peergrouplevel = 8
			AND r.mediandv < .9

			delete
			from ppbfact 
			from ppbfact p
			join 
			dbo.PPBRunResults r
			ON	p.ProductLineBucket			=	r.ProductLineBucket
			AND r.peergrouplevel = 8

			set @insertcount= @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Populate ppboutput with peergrouplevels 8'

        /*--------------------------------------------------------------------------------------------*/
        /*------11. Apply to factorders --------------------------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Apply to factorders'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

			IF  NOT EXISTS (SELECT * FROM sys.indexes 
			WHERE object_id = OBJECT_ID(N'[dbo].[FactOrders]') 
			AND name = N'ix_gb')
			CREATE INDEX [ix_gb] 
			ON [dbo].[FactOrders] ([GoldBookPrice] ,[trankey]) 
			INCLUDE ( [SalesDollars]) 

				update factorders
				set peergrouplevel = p.peergrouplevel ,
				peerprice = p.mediandv,
				ExtendedPEERPRICE =
				CASE WHEN  salesdollars/((1-mediandv)*goldbookprice) > = 2.0
				THEN SalesDollars
				ELSE ((1-mediandv)*goldbookprice) END
				from factorders f
				join ppboutput p
				on f.trankey = p.trankey
				and p.mediandv <> 1
				and f.goldbookprice > 0


				update factorders 
				set
				ExtendedPEERPRICE = salesdollars
				WHERE ExtendedPEERPRICE = 0
				OR 
				(
				ExtendedPEERPRICE <> 0
				AND 
				round(SalesDollars/ExtendedPEERPRICE,0) > 3
				)

				update factorders 
				set
				ExtendedPEERPRICE = .0000001,
				salesdollars = .0000001
				where ExtendedPEERPRICE = 0
				and salesdollars = 0

			set @insertcount= @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Apply to factorders'


/*----------------------------------END----------------------------*/

			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName
			exec sp_logEndSection @processName

    end try
    begin catch
        exec sp_logAndRethrowError     
    end catch
end
GO

-- %% [markdown]
-- # [dbo].[spr_ProcessFixedDimensions]

-- %%
/****** Object:  StoredProcedure [dbo].[spr_ProcessFixedDimensions]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[spr_ProcessFixedDimensions]
as 
begin
/*
Populates all 13 tables using fixed data for T&B

Change History
=================
06/10/08	aminkin		Initial Creation
*/


DROP TABLE [dbo].[DimABCMatrix]

CREATE TABLE [dbo].[DimABCMatrix](
	[abccode] [varchar](10) NULL,
	[abcdesc] [varchar](10) NULL
) ON [PRIMARY]

INSERT INTO DimABCMatrix (abccode,abcdesc) Values ('?','zUnknown')
INSERT INTO DimABCMatrix (abccode,abcdesc) Values ('A','A')
INSERT INTO DimABCMatrix (abccode,abcdesc) Values ('B','B')
INSERT INTO DimABCMatrix (abccode,abcdesc) Values ('C','C')
INSERT INTO DimABCMatrix (abccode,abcdesc) Values ('E','E')
INSERT INTO DimABCMatrix (abccode,abcdesc) Values ('N','N')
          
DROP TABLE[DimSpa]

CREATE TABLE DimSpa
(
SPaKey int,
Credit varchar (5),
CreditType varchar(20)
)

INSERT INTO DImSPa (SPaKey, Credit, CreditType) Values (1,'No','Invoice')
INSERT INTO DImSPa (SPaKey, Credit, CreditType) Values (2,'Yes','POS')
INSERT INTO DImSPa (SPaKey, Credit, CreditType) Values (3,'Yes','Other-R')
INSERT INTO DImSPa (SPaKey, Credit, CreditType) Values (4,'Yes','Non-SPA')
INSERT INTO DImSPa (SPaKey, Credit, CreditType) Values (5,'Yes','SPA')
INSERT INTO DImSPa (SPaKey, Credit, CreditType) Values (6,'Yes','Concessions')
INSERT INTO DImSPa (SPaKey, Credit, CreditType) Values (7,'Yes','VID')
INSERT INTO DImSPa (SPaKey, Credit, CreditType) Values (8,'Yes','Misc. Charges')

DROP TABLE 
[dbo].[DimOrderSize]

CREATE TABLE 
[dbo].[DimOrderSize](
	[OrderSizeKey] [int] NOT NULL,
	[OrderSize] [varchar](20) NULL
) ON [PRIMARY]


INSERT INTO DimOrderSize (OrderSizeKey, OrderSize) Values (0,'Small')
INSERT INTO DimOrderSize (OrderSizeKey, OrderSize) Values (1,'Large')
INSERT INTO DimOrderSize (OrderSizeKey, OrderSize) Values (-1,'zUnknown')

DROP TABLE [dbo].[dimPriceSource]
CREATE TABLE [dbo].[dimPriceSource](
	[PriceSource] [varchar](20) NULL,
	[PriceSourceDesc] [varchar](21) NOT NULL
) ON [PRIMARY]

INSERT INTO dimPriceSource (PriceSource, PriceSourceDesc) Values ('zUnknown','zUnknown PriceSource')
INSERT INTO dimPriceSource (PriceSource, PriceSourceDesc) Values ('CUF','Cust Net Sheet Disc')
INSERT INTO dimPriceSource (PriceSource, PriceSourceDesc) Values ('KGF','Comp Group Disc')
INSERT INTO dimPriceSource (PriceSource, PriceSourceDesc) Values ('KIF','Item Price')
INSERT INTO dimPriceSource (PriceSource, PriceSourceDesc) Values ('KLF','Comp Line Disc')
INSERT INTO dimPriceSource (PriceSource, PriceSourceDesc) Values ('KSF','Comp Sub Group Disc')
INSERT INTO dimPriceSource (PriceSource, PriceSourceDesc) Values ('MANUL','Manual')
INSERT INTO dimPriceSource (PriceSource, PriceSourceDesc) Values ('NSF','Net Sheet')
INSERT INTO dimPriceSource (PriceSource, PriceSourceDesc) Values ('QUO','Quote')

DROP TABLE [dbo].[DimQuoteFlag]

CREATE TABLE [dbo].[DimQuoteFlag](
	[QuoteFlagKey] [int] NULL,
	[QuoteFlagDesc] [varchar](50) NULL
) ON [PRIMARY]

INSERT INTO DimQuoteFlag (QuoteFlagKey, QuoteFlagDesc) Values (1,'NonQuoted')
INSERT INTO DimQuoteFlag (QuoteFlagKey, QuoteFlagDesc) Values (2,'Quoted')
INSERT INTO DimQuoteFlag (QuoteFlagKey, QuoteFlagDesc) Values (3,'Stock')


DROP TABLE [dbo].[DimTimeUtility]

CREATE TABLE [dbo].[DimTimeUtility](
	[TimeUtilityKey] [tinyint] NOT NULL,
	[TimeUtilityDesc] [varchar](10) NOT NULL,
 CONSTRAINT [PK_DIMTIMEUTILITY] PRIMARY KEY CLUSTERED 
(
	[TimeUtilityKey] ASC
)WITH (PAD_INDEX  = OFF, STATISTICS_NORECOMPUTE  = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS  = ON, ALLOW_PAGE_LOCKS  = ON) ON [PRIMARY]
) ON [PRIMARY]

INSERT INTO DimTimeUtility (TimeUtilityKey, TimeUtilityDesc) VALUES (1,1)

END
GO

-- %% [markdown]
-- # [dbo].[spr_purgeFactTables]

-- %%
/****** Object:  StoredProcedure [dbo].[spr_purgeFactTables]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
create procedure [dbo].[spr_purgeFactTables]
as 
begin

    begin try 
        declare @processName varchar(100)
        -- initialize parameters
        set @processName = 'spr_purgeFactTables'
        declare @factTableName  varchar(255) 
        declare @datePart       varchar(255)   
        declare @periodLen      varchar(255) 
        declare @dateKeyCol     varchar(255) 
        declare @strSQLStmt     nvarchar(max)
        declare @delRowsCount   int
        declare @errorMsg       varchar(255)
        set @errorMsg = '' 

        set @factTableName = (select min(purgeFactTable) from MetaUtilDBPurge)      
        while 1 = 1 
        begin
            exec sp_logWrite @action = 'START', @logLevel = 'INFO',  @processName = @processName, @tblName = @factTableName, @logText = 'Starting of table purging'
            ----------------------------------------------------------------------
            -- getting param values for the given factTable
            ----------------------------------------------------------------------
            select @datePart   = datePart,
                   @dateKeyCol = dateKeyColumn,
                   @periodLen  = periodLen
              from MetaUtilDBPurge
             where purgeFactTable = @factTableName 
            -- table purging
            set @strSQLStmt = 'delete from ' + @factTableName 
            set @strSQLStmt = @strSQLStmt + ' where datediff(' + @datePart + ', convert(datetime, convert(char(8), ' + @dateKeyCol + ')), getdate()) > @pl; set @rc=@@rowcount'
            set @delRowsCount = 0 
            begin try 
                exec sp_executeSQL @strSQLStmt,
                                   N'@pl int, @rc int OUTPUT',
                                   @pl = @periodLen,
                                   @rc = @delRowsCount OUTPUT
                exec sp_logWrite @action = 'STOP', @logLevel = 'INFO', @processName = @processName, @logText = 'Successful Run', @tblName = @factTableName, @deleteCount = @delRowsCount    
            end try
            begin catch
                set @errorMsg = 'Error: the set of parameters: purgeFactTable = '''+ @factTableName +''', ' + 
                                                               'datePart = '''+ @datePart +''', ' + 
                                                               'dateKeyColumn = '''+ @dateKeyCol +''', ' +  
                                                               'periodLength = '''+ @periodLen +''' ' +  
                                 'are incorrect. The purge has not been performed!'
                exec sp_logWrite @logLevel = 'FATAL', @processName = @processName, @logText = @errorMsg, @tblName = @factTableName
            end catch

            
            -- getting next table 
            set @factTableName = (select min(purgeFactTable) from MetaUtilDBPurge where purgeFactTable > @factTableName)
            if @factTableName is null break 
        end 
        /*--------------------------------------------------------------------------------------------*/
        
        if @errorMsg <> '' 
            raiserror (N'Not all purge operation were performed. See logTable for more details.', 16, 1)
        
    end try
    begin catch
        exec sp_logAndRethrowError     
    end catch
    
end
GO

-- %% [markdown]
-- # [dbo].[spr_sc_dq_ColumnDetail]

-- %%
/****** Object:  StoredProcedure [dbo].[spr_sc_dq_ColumnDetail]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
CREATE PROCEDURE [dbo].[spr_sc_dq_ColumnDetail] 
	@full_name		nvarchar(700),
	@column_name	nvarchar(256)
AS
BEGIN
SET NOCOUNT ON
DECLARE 
	@SQLStr varchar(4000)

SET @SQLStr = 'SELECT Top_TargetCol, Top_Occurs, Bottom_TargetCol, Bottom_Occurs, c.* '+
				' FROM (SELECT TOP (15) ROW_NUMBER() OVER(ORDER BY COUNT(*) DESC) AS ID, ' + @column_name + ' AS Top_TargetCol, COUNT(*) AS Top_Occurs FROM '  + @full_name + ' GROUP BY ' +  @column_name + ' ORDER BY Top_Occurs DESC) a FULL JOIN '+
				'(SELECT TOP (15) ROW_NUMBER() OVER(ORDER BY COUNT(*)) AS ID, ' + @column_name + ' AS Bottom_TargetCol, COUNT(*) AS Bottom_Occurs FROM '  + @full_name + ' GROUP BY ' +  @column_name + ' ORDER BY Bottom_Occurs) b ON a.ID = b.ID , '+ 
				'(SELECT COUNT(*) AS Row_Count, COUNT(DISTINCT ' + @column_name + ') AS Unique_Values  FROM  ' + @full_name + ') c ORDER BY a.ID, b.ID '
EXECUTE(@SQLStr)
END
GO

-- %% [markdown]
-- # [dbo].[spr_sc_dq_ColumnList]

-- %%
/****** Object:  StoredProcedure [dbo].[spr_sc_dq_ColumnList]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
CREATE PROCEDURE [dbo].[spr_sc_dq_ColumnList] 
   @database_name	nvarchar(128),
   @schema_name		nvarchar(256),
   @table_name		nvarchar(256) 
AS
BEGIN
SET NOCOUNT ON

CREATE TABLE #tmp_TableColumns(
	column_name sysname,
	data_type nvarchar(128),
	ordinal_position bigint,
	max_length bigint,
	row_count bigint)

CREATE TABLE #tmp_ColumnProfile(
	TableName varchar(256),
	ColumnName varchar(256),
	OrdinalPosition bigint,
	DataType varchar (60),
	MaxLength bigint,
	MinValue nvarchar(max),
	MaxValue nvarchar(max),
	DistinctValues bigint, 
	NullCount bigint,
	RowsCount bigint,
	AvgLengthOrValue bigint,
	MaxCharLength bigint)

DECLARE 
	@ColName varchar(256), 
	@OrdinalPosition bigint,
	@DataType varchar(60), 
	@MaxLength bigint,
	@RowsCount bigint,
	@MaxLengthTmp bigint,
	@SQLStr varchar(4000)

SET @SQLStr =	'SELECT column_name, data_type, ordinal_position, ISNULL(character_maximum_length,0) + ISNULL(numeric_precision,0) + ISNULL(datetime_precision,0) AS max_length, '+
				'(SELECT COUNT(*) FROM ' + @database_name + '.' + @schema_name + '.[' + @table_name + '])AS row_count ' +
				'FROM ' + @database_name + '.INFORMATION_SCHEMA.COLUMNS ' +
				'WHERE table_schema = ''' + @schema_name + ''' AND table_name =''' + @table_name +''''

INSERT INTO #tmp_TableColumns EXECUTE(@SQLStr)

DECLARE ColCursor CURSOR FOR 
	SELECT * FROM #tmp_TableColumns
	ORDER BY Ordinal_Position

OPEN ColCursor

FETCH NEXT FROM ColCursor 
INTO   @ColName, @DataType, @OrdinalPosition, @MaxLengthTmp, @RowsCount

WHILE @@FETCH_STATUS = 0
BEGIN
	SET @MaxLength = @MaxLengthTmp
	IF @DataType = 'bit' SET @MaxLength = 1
	IF @DataType = 'uniqueidentifier' SET @MaxLength = 16
	IF @DataType = 'datetime' SET @MaxLength = 8
	IF @DataType = 'smalldatetime' SET @MaxLength = 4
	IF @DataType = 'xml' SET @MaxLength = NULL

--	PRINT '>>> Getting Column Name: ''' + @ColName + ''', MaxLength: ' + CAST(ISNULL(@MaxLength,0) AS varchar(10))
-- Create a SQL string to insert column info depending on the data type of the given column
	IF @DataType IN ('int', 'bigint', 'smallint', 'tinyint', 
		'money', 'smallmoney', 'decimal', 'numeric',
		'float', 'real')
	BEGIN  -- handle most numeric data types
		SELECT @SQLStr = 'INSERT INTO #tmp_ColumnProfile SELECT ''' + @table_name +
			''' TableName, ''' + @ColName + ''' ColName, ' + 
			CAST (@OrdinalPosition AS varchar(12)) + ' OrdPos, ''' + @DataType + '(' +
			CAST(ISNULL(  @MaxLength  ,0) AS varchar(12)) + ')' +
			''' DataType, ' + CAST(ISNULL(@MaxLength, 0) AS varchar(12)) + 
			' Lngth, MIN([' + @ColName + ']) MIN, MAX([' + 
			@ColName + ']) MAX, COUNT(DISTINCT [' + @ColName + ']) DistinctVals, ' + 
			'SUM(CASE WHEN [' + @ColName + '] IS NULL THEN 1 ELSE 0 END) NullCount, ' + 
			LTRIM(@RowsCount) +' AS RowsCount, ' +	
			' AVG( [' + @ColName + ']*1.0) AvgValue, ' +  
			' NULL MaxLength' +
			' FROM ' + @database_name + '.' + @schema_name + '.[' + @table_name +']'
	END
	ELSE
	IF @DataType IN ('char', 'varchar', 'nvarchar', 'nchar') -- handle character string data types
	BEGIN 
		SELECT @SQLStr = 'INSERT INTO #tmp_ColumnProfile SELECT ''' + 
			@table_name + ''' TableName, ''' + @ColName + 
			''' ColName, ' + CAST (@OrdinalPosition AS varchar(12)) + 
			' OrdPos, ''' + @DataType + '(' + 
			CAST(ISNULL(  @MaxLength  ,0) AS varchar(12)) + ')' +
			''' DataType, ' + CAST(ISNULL(@MaxLength, 0) AS varchar(12)) + 
			' Lngth, MIN([' + @ColName + ']) MIN, MAX([' + 
			@ColName + ']) MAX, COUNT(DISTINCT [' + @ColName + ']) DistinctVals, ' + 
			'SUM(CASE WHEN [' + @ColName + 
			'] IS NULL THEN 1 ELSE 0 END) NullCount, ' + 
			LTRIM(@RowsCount) +' AS RowsCount, ' +
			' AVG(len( [' + @ColName + ']))  AvgValue, ' +
			' MAX(len( [' + @ColName + ']))  MaxLength ' +  
			' FROM ' + @database_name + '.' + @schema_name + '.[' + @table_name +']'
	END
	ELSE
	IF @DataType IN ('datetime', 'smalldatetime', 'timestamp') -- handle date data types
	BEGIN  
		SELECT @SQLStr = 'INSERT INTO #tmp_ColumnProfile SELECT ''' + @table_name +
			''' TableName, ''' + @ColName + ''' ColName, ' + 
			CAST (@OrdinalPosition AS varchar(12)) + ' OrdPos, ''' + @DataType + '(' +
			CAST(ISNULL(  @MaxLength  ,0) AS varchar(12)) + ')' +
			''' DataType, ' + CAST(ISNULL(@MaxLength, 0) AS varchar(12)) + 
			' Lngth, MIN([' + @ColName + ']) MIN, MAX([' + 
			@ColName + ']) MAX, COUNT(DISTINCT [' + @ColName + ']) DistinctVals, ' + 
			'SUM(CASE WHEN [' + @ColName + '] IS NULL THEN 1 ELSE 0 END) NullCount, ' + 
			LTRIM(@RowsCount) +' AS RowsCount, ' +
			' NULL AvgLength, ' +
			--      ' CAST(Avg(CAST( ' + @ColName + ' AS int)) AS datetime) AvgValue, ' +  
			' NULL MaxLength' +
			' FROM ' + @database_name + '.' + @schema_name + '.[' + @table_name +']'
	END   
	ELSE
	IF @DataType IN ('xml', 'uniqueidentifier', 'binary', 'varbinary', 'image', 'bit', 'text', 'ntext') -- Handle XML and other odd data types
	BEGIN 
		SELECT @SQLStr = 'INSERT INTO #tmp_ColumnProfile SELECT ''' + @table_name +
			''' TableName, ''' + @ColName + ''' ColName, ' + 
			CAST (@OrdinalPosition AS varchar(12)) + ' OrdPos, ''' + @DataType + 
			''' DataType, ' + CAST(ISNULL(@MaxLength, 0) AS varchar(12)) + 
			' Lngth, ''n/a'' MIN, ''n/a'' MAX, 0 DistinctVals, ' + 
			'SUM(CASE WHEN [' + @ColName + '] IS NULL THEN 1 ELSE 0 END) NullCount, ' + 
			LTRIM(@RowsCount) +' AS RowsCount, ' +
			' NULL AvgValue, ' +
			' NULL MaxValue ' +
			' FROM ' + @database_name + '.' + @schema_name + '.[' + @table_name +']'
	END
	ELSE
	BEGIN -- Unidentified data types
		PRINT 'Need a section to handle this data type: ' + @DataType
	END
	EXEC(@SQLStr)
	FETCH NEXT FROM ColCursor 
	INTO @ColName, @DataType, @OrdinalPosition, @MaxLengthTmp, @RowsCount
END -- of cursor column processing
-- Write out the final results for the RS Dataset
SELECT 
	*,
	NullCount / (1.0 * NULLIF(RowsCount,0)) AS PctNull
FROM #tmp_ColumnProfile
ORDER BY OrdinalPosition
-- Clean house
CLOSE ColCursor
DEALLOCATE ColCursor
DROP TABLE #tmp_ColumnProfile
DROP TABLE #tmp_TableColumns
END
GO

-- %% [markdown]
-- # [dbo].[spr_sc_dq_TableList]

-- %%
/****** Object:  StoredProcedure [dbo].[spr_sc_dq_TableList]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER OFF
GO
CREATE PROCEDURE [dbo].[spr_sc_dq_TableList] 
	@database_name nvarchar(128)
AS
BEGIN
SET NOCOUNT ON

CREATE TABLE #tmp_TableProfile
   (id	int,
	full_name   sysname, 
    schema_name sysname,
    table_name  sysname,
    col_count   int)

CREATE TABLE #tmp_SpaceUsed
	(id int,
	reserved_page_count bigint,
	used_page_count bigint,
	pages bigint,
	row_count bigint)


DECLARE @SQLStr nvarchar(4000)

SET @SQLStr =	'SELECT object_id('''+ @database_name + '.''+t.table_schema+''.''+t.table_name), t.table_schema+''.''+t.table_name, t.table_schema, t.table_name, '+
				'COUNT(c.column_name) AS col_count FROM '+ @database_name + 
				'.INFORMATION_SCHEMA.TABLES t INNER JOIN '+ @database_name + 
				'.INFORMATION_SCHEMA.COLUMNS c ON t.table_schema = c.table_schema AND t.table_name = c.table_name ' +
				'WHERE t.table_type = ''BASE TABLE'' GROUP BY t.table_schema, t.table_name '
INSERT INTO #tmp_TableProfile(id,full_name,schema_name,table_name,col_count) EXECUTE(@SQLStr)

SET @SQLStr = 'SELECT 
			object_id,
			--OBJECT_NAME(object_id) table_name,
			SUM(reserved_page_count) + ISNULL(MIN(xml_reserved_page_count),0) AS reserved_page_count,
			SUM(used_page_count) + ISNULL(MIN(xml_used_page_count),0) AS used_page_count,
			SUM(
				CASE
					WHEN (index_id < 2) THEN (in_row_data_page_count + lob_used_page_count + row_overflow_used_page_count)
					ELSE lob_used_page_count + row_overflow_used_page_count
				END
				) AS pages,
			SUM (
				CASE
					WHEN (index_id < 2) THEN row_count
					ELSE 0
				END
				) AS sp_row_count
		FROM ' + @database_name + '.sys.dm_db_partition_stats s LEFT JOIN  
			--
			-- Check if table has XML Indexes or Fulltext Indexes which use internal tables tied to this table
			--
			(SELECT it.parent_id, 
					SUM(resers XML Indexes or Fulltext Indexes which use internal tables tied to this table
			--
			(SELECT it.parent_id, 
					SUM(reserved_page_count) xml_reserved_page_count,
					SUM(used_page_count) xml_used_page_count
				FROM ' + @database_name + '.sys.dm_db_partition_stats p, ' + @database_name + '.sys.internal_tables it
				WHERE it.internal_type IN (202,204) AND p.object_id = it.object_id GROUP BY it.parent_id) x ON x.parent_id = s.object_id 
		WHERE s.object_id IN (SELECT object_id('''+ @database_name + '.''+table_schema+''.''+table_name) FROM '+ @database_name + '.INFORMATION_SCHEMA.TABLES WHERE table_type = ''BASE TABLE'')
		GROUP BY s.object_id' 

INSERT INTO #tmp_SpaceUsed EXECUTE(@SQLStr)

SELECT 
	t.*,
	s.row_count, 
	LTRIM (reserved_page_count * 8) + ' KB' AS reserved_space,
	LTRIM (pages * 8) + ' KB' AS data_space,
	LTRIM ((CASE WHEN used_page_count > pages THEN (used_page_count - pages) ELSE 0 END) * 8) + ' KB' AS index_space,
	LTRIM ((CASE WHEN reserved_page_count > used_page_count THEN (reserved_page_count - used_page_count) ELSE 0 END) * 8) + ' KB' AS unused_space
FROM #tmp_SpaceUsed s INNER JOIN #tmp_TableProfile t ON t.id = s.id
ORDER BY t.table_name

END
GO

-- %% [markdown]
-- # [dbo].[spr_ScorecardProcessingPriceIndex]

-- %%
/****** Object:  StoredProcedure [dbo].[spr_ScorecardProcessingPriceIndex]    Script Date: 5/17/2022 11:50:23 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[spr_ScorecardProcessingPriceIndex] as
begin


/*
exec spr_ScorecardProcessingPriceIndex

select * from FactOrders

select top 1 * from orders
select top 1 * from FactOrders
select top 1 * from DimProduct
select top 1 * from DimCustomer
select top 1 * from DimRQM
select top 1 * from DimDate
select top 1 * from DimCurrency


select * from logTable where processName = 'spr_ScorecardProcessingPriceIndex'
truncate table logTable
*/

/*
History
==================
06/10/2008	aminkin		Initial creation
*/

/*
Goals
1. Generate PPB lookup for CatalogNuber
2. Generate PPB lookup for productvelocity
3. Generate PPB lookup for prodgroup
4. Generate PPB lookup for prodgroupdv
5. Generate PPB lookup for ProductLineBucket
6. Generate PI lookup for CatalogNumber
7. Generate PI lookup for prodgroup
8. Generate PI lookup for Prodline
*/

--1.	 Add additional ETL
--a.	Add five columns to DImProduct for calculations: . available for each product.  
--b.	Apply Median_DV from PPBRunResults  where possible navigating tree as outlined before
--c.	Go to transactions to find average mediandv where value not found in PPBRun Results
/*
SL	Friendly Name				PGL DimProductDV	DimproductKey		PBRunResultsKey
===============================================================================================
1	Productlinebucket			8	ProdLine_DV		ProductLineBucket	ProductLineBucket
2	new_productgroupbucket		7	ProdGrpVel_DV	prodgroupdv			ProductGroupBucket
3	prodgroup					6	ProdGrp_DV		prodgroup			ProductGroup
4	new_prodvelocity			5	ProdVel_DV		productvelocity		ProductVelocity
5	productid (catalognumber)	4	CatNum_DV		Catalognumber		productkey
*/

--alter table dimproduct add CatNum_DV numeric (16,9)
--alter table dimproduct add ProdGrp_DV numeric (16,9)
--alter table dimproduct add ProdGrpVel_DV numeric (16,9)
--alter table dimproduct add ProdLine_DV numeric (16,9)
--alter table dimproduct add ProdVel_DV numeric (16,9)
--select avg(mediandv) from ppbrunresults
--0.5119158449
/*
For scorecard:
Product Line Search only peergrouplevel =8 in PPBRunResults looking for a match to get mediandv.  
Product Group Search peergrouplevel 6-8 (one query per level, staring with 6) in PPBRunResults until you find a match to get mediandv
Catalog Number Search peergrouplevel 3-8 (one query per level, staring with 3) in PPBRunResults until you find a match to get mediandv
*/

begin try


-- logging parameters
declare @processName varchar(100)
declare @tableName varchar(50)
declare @finalTableRowCount int
declare @logID int
declare @updateCount int
declare @insertCount int
-- initialize parameters
set @processName = 'spr_ScorecardProcessingPriceIndex'
set @tableName = 'FactOrders'


exec sp_logBeginSection @processName
exec sp_logWrite @action = 'START', 
	@logLevel = 'INFO', 
	@processName = @processName, 
	@tblName = @tableName,
	@logText = @processName

				declare @fallbackdv numeric(16,9)
				set @fallbackdv =
				(select avg(((goldbookprice * (1-peerprice))- salesdollars)/salesdollars)
				from factorders f
				where f.quantity > 0 and f.salesdollars > 0 and f.spakey =1)
				--@fallbackdv

        /*--------------------------------------------------------------------------------------------*/
        /*------1. Generate PPB lookup for CatalogNuber-----------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Generate PPB lookup for CatalogNuber'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName


				Update dimproduct set CatNum_DV =P.mediandv
				from dimproduct R
				join 
				ppbrunresults P
				ON	P.ProductLineBucket		= R.ProductLineBucket		
				AND	P.ProductGroupBucket	= R.prodgroupdv		
				AND	P.ProductGroup			= R.prodgroup		
				AND	P.ProductVelocity		= R.productvelocity	
				AND	P.productkey			= R.Catalognumber	
				WHERE CatNum_DV IS NULL
				AND peergrouplevel = 4

				Update dimproduct set CatNum_DV =P.mediandv
				from dimproduct R
				join 
				ppbrunresults P
				ON	P.ProductLineBucket		= R.ProductLineBucket		
				AND	P.ProductGroupBucket	= R.prodgroupdv		
				AND	P.ProductGroup			= R.prodgroup		
				AND	P.ProductVelocity		= R.productvelocity	
				--AND	P.productkey			= R.Catalognumber	
				WHERE CatNum_DV IS NULL
				AND peergrouplevel = 5

				Update dimproduct set CatNum_DV =P.mediandv
				from dimproduct R
				join 
				ppbrunresults P
				ON	P.ProductLineBucket		= R.ProductLineBucket		
				AND	P.ProductGroupBucket	= R.prodgroupdv		
				AND	P.ProductGroup			= R.prodgroup		
				--AND	P.ProductVelocity		= R.productvelocity	
				--AND	P.productkey			= R.Catalognumber	
				WHERE CatNum_DV IS NULL
				AND peergrouplevel = 6

				Update dimproduct set CatNum_DV =P.mediandv
				from dimproduct R
				join 
				ppbrunresults P
				ON	P.ProductLineBucket		= R.ProductLineBucket		
				AND	P.ProductGroupBucket	= R.prodgroupdv		
				--AND	P.ProductGroup			= R.prodgroup		
				--AND	P.ProductVelocity		= R.productvelocity	
				--AND	P.productkey			= R.Catalognumber	
				WHERE CatNum_DV IS NULL
				AND peergrouplevel = 7

				Update dimproduct set CatNum_DV =P.mediandv
				from dimproduct R
				join 
				ppbrunresults P
				ON	P.ProductLineBucket		= R.ProductLineBucket		
				WHERE CatNum_DV IS NULL
				AND peergrouplevel = 8

				IF  EXISTS (SELECT * FROM sys.objects WHERE object_id 
				= OBJECT_ID(N'[dbo].[prodkeydv]'))
				DROP table prodkeydv

				select f.productkey, avg(((goldbookprice * (1-peerprice))- salesdollars)/salesdollars) peerprice
				into prodkeydv
				from dimproduct p
				join factorders f
				on f.productkey = p.productkey
				where p.CatNum_DV is null
				and f.quantity > 0 and f.salesdollars > 0 and spakey =1  and goldbookprice > 0
				group by f.productkey

				update dimproduct set CatNum_DV = f.peerprice
				from dimproduct p
				join prodkeydv f
				on f.productkey = p.productkey
				where CatNum_DV is null

				update dimproduct 
				set CatNum_DV  = @fallbackdv
				where CatNum_DV is null or CatNum_DV = 0

			set @insertcount= @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Generate PPB lookup for CatalogNuber'

        /*--------------------------------------------------------------------------------------------*/
        /*------2. Generate PPB lookup for productvelocity-----------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Generate PPB lookup for productvelocity'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

				/*
				============================================================================
				PRODUCT VELOCITY
				============================================================================
				*/

				Update dimproduct set ProdVel_DV =P.mediandv
				from dimproduct R
				join 
				ppbrunresults P
				ON	P.ProductLineBucket		= R.ProductLineBucket		
				AND	P.ProductGroupBucket	= R.prodgroupdv		
				AND	P.ProductGroup			= R.prodgroup		
				AND	P.ProductVelocity		= R.productvelocity	
				WHERE ProdVel_DV IS NULL
				AND peergrouplevel = 5

				Update dimproduct set ProdVel_DV =P.mediandv
				from dimproduct R
				join 
				ppbrunresults P
				ON	P.ProductLineBucket		= R.ProductLineBucket		
				AND	P.ProductGroupBucket	= R.prodgroupdv		
				AND	P.ProductGroup			= R.prodgroup		
				WHERE ProdVel_DV IS NULL
				AND peergrouplevel = 6

				Update dimproduct set ProdVel_DV =P.mediandv
				from dimproduct R
				join 
				ppbrunresults P
				ON	P.ProductLineBucket		= R.ProductLineBucket		
				AND	P.ProductGroupBucket	= R.prodgroupdv			
				WHERE ProdVel_DV IS NULL
				AND peergrouplevel = 7

				Update dimproduct set ProdVel_DV =P.mediandv
				from dimproduct R
				join 
				ppbrunresults P
				ON	P.ProductLineBucket		= R.ProductLineBucket			
				WHERE ProdVel_DV IS NULL
				AND peergrouplevel = 8


				IF  EXISTS (SELECT * FROM sys.objects WHERE object_id 
				= OBJECT_ID(N'[dbo].[prodvelokeydv]'))
				DROP table prodvelokeydv

				select p.productvelocity, avg(((goldbookprice * (1-peerprice))- salesdollars)/salesdollars) peerprice
				into prodvelokeydv
				from dimproduct p
				join factorders f
				on f.productkey = p.productkey
				where p.ProdVel_DV is null
				and f.quantity > 0 and f.salesdollars > 0 and spakey =1 and goldbookprice > 0
				group by p.productvelocity

				update dimproduct set ProdVel_DV = f.peerprice
				from dimproduct p
				join prodvelokeydv f
				on f.productvelocity = p.productvelocity
				where ProdVel_DV is null or ProdVel_DV = 0

				update dimproduct 
				set ProdVel_DV  = @fallbackdv
				where ProdVel_DV is null or ProdVel_DV = 0

			set @insertcount= @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Generate PPB lookup for productvelocity'

        /*--------------------------------------------------------------------------------------------*/
        /*------3. Generate PPB lookup for prodgroup-----------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Generate PPB lookup for prodgroup'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

				/*
				============================================================================
				PRODUCT GROUP ProdGrp_DV, ProdGrpVel_DV, ProdLine_DV
				============================================================================
				*/

				Update dimproduct set ProdGrp_DV =P.mediandv
				from dimproduct R
				join 
				ppbrunresults P
				ON	P.ProductLineBucket		= R.ProductLineBucket		
				AND	P.ProductGroupBucket	= R.prodgroupdv		
				AND	P.ProductGroup			= R.prodgroup			
				WHERE ProdGrp_DV IS NULL
				AND peergrouplevel = 6

				Update dimproduct set ProdGrp_DV =P.mediandv
				from dimproduct R
				join 
				ppbrunresults P
				ON	P.ProductLineBucket		= R.ProductLineBucket		
				AND	P.ProductGroupBucket	= R.prodgroupdv		
				WHERE ProdGrp_DV IS NULL
				AND peergrouplevel = 7

				Update dimproduct set ProdGrp_DV =P.mediandv
				from dimproduct R
				join 
				ppbrunresults P
				ON	P.ProductLineBucket		= R.ProductLineBucket		
				WHERE ProdGrp_DV IS NULL
				AND peergrouplevel = 8

				IF  EXISTS (SELECT * FROM sys.objects WHERE object_id 
				= OBJECT_ID(N'[dbo].[prodgrpkeydv]'))
				drop table prodgrpkeydv

				select p.prodgroup, avg(((goldbookprice * (1-peerprice))- salesdollars)/salesdollars) peerprice
				into prodgrpkeydv
				from dimproduct p
				join factorders f
				on f.productkey = p.productkey
				where p.ProdGrp_DV is null
				and f.quantity > 0 and f.salesdollars > 0 and spakey =1  and goldbookprice > 0
				group by p.prodgroup

				update dimproduct set ProdGrp_DV = f.peerprice
				from dimproduct p
				join prodgrpkeydv f
				on f.prodgroup = p.prodgroup
				where ProdGrp_DV is null or ProdGrp_DV = 0

				update dimproduct 
				set ProdGrp_DV  = @fallbackdv
				where ProdGrp_DV is null or ProdGrp_DV = 0

			set @insertcount= @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Generate PPB lookup for prodgroup'

        /*--------------------------------------------------------------------------------------------*/
        /*------4. Generate PPB lookup for prodgroupdv-----------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Generate PPB lookup for prodgroupdv'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

				/*
				============================================================================
				PRODUCT GROUP BUCKET ProdGrpVel_DV, ProdLine_DV
				============================================================================
				*/

				Update dimproduct set ProdGrpVel_DV =P.mediandv
				from dimproduct R
				join 
				ppbrunresults P
				ON	P.ProductLineBucket		= R.ProductLineBucket		
				AND	P.ProductGroupBucket	= R.prodgroupdv		
				WHERE ProdGrpVel_DV IS NULL
				AND peergrouplevel = 7

				Update dimproduct set ProdGrpVel_DV =P.mediandv
				from dimproduct R
				join 
				ppbrunresults P
				ON	P.ProductLineBucket		= R.ProductLineBucket		
				WHERE ProdGrpVel_DV IS NULL
				AND peergrouplevel = 8

				IF  EXISTS (SELECT * FROM sys.objects WHERE object_id 
				= OBJECT_ID(N'[dbo].[prodgrplvlkeydv]'))
				drop table prodgrplvlkeydv

				select p.prodgroupdv, avg(((goldbookprice * (1-peerprice))- salesdollars)/salesdollars) peerprice
				into prodgrplvlkeydv
				from dimproduct p
				join factorders f
				on f.productkey = p.productkey
				where p.ProdGrpVel_DV is null
				and f.quantity > 0 and f.salesdollars > 0 and spakey =1  and goldbookprice > 0
				group by p.prodgroupdv

				update dimproduct set ProdGrpVel_DV = f.peerprice
				from dimproduct p
				join prodgrplvlkeydv f
				on f.prodgroupdv = p.prodgroupdv
				where ProdGrpVel_DV is null or ProdGrpVel_DV = 0

				update dimproduct 
				set ProdGrpVel_DV  = @fallbackdv
				where ProdGrpVel_DV is null or ProdGrpVel_DV = 0

			set @insertcount= @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Generate PPB lookup for prodgroupdv'

        /*--------------------------------------------------------------------------------------------*/
        /*------5. Generate PPB lookup for ProductLineBucket-----------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Generate PPB lookup for ProductLineBucket'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

				/*
				============================================================================
				PRODUCT LINE ProdLine_DV
				============================================================================
				*/

				Update dimproduct set ProdLine_DV =P.mediandv
				from dimproduct R
				join 
				ppbrunresults P
				ON	P.ProductLineBucket		= R.ProductLineBucket			
				WHERE ProdLine_DV IS NULL
				AND peergrouplevel = 8

				IF  EXISTS (SELECT * FROM sys.objects WHERE object_id 
				= OBJECT_ID(N'[dbo].[prodlinekeydv]'))
				drop table prodlinekeydv

				select p.ProductLineBucket, avg(((goldbookprice * (1-peerprice))- salesdollars)/salesdollars) peerprice
				into prodlinekeydv
				from dimproduct p
				join factorders f
				on f.productkey = p.productkey
				where p.ProdLine_DV is null
				and f.quantity > 0 and f.salesdollars > 0 and spakey =1  and goldbookprice > 0
				group by p.ProductLineBucket

				update dimproduct set ProdLine_DV = f.peerprice
				from dimproduct p
				join prodlinekeydv f
				on f.ProductLineBucket = p.ProductLineBucket
				where ProdLine_DV is null or ProdLine_DV = 0
				--sp_who
				update dimproduct 
				set ProdLine_DV  = @fallbackdv
				where ProdLine_DV is null or ProdLine_DV = 0

			set @insertcount= @@rowcount
			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Generate PPB lookup for ProductLineBucket'

        /*--------------------------------------------------------------------------------------------*/
        /*------6. Generate Scorecard lookup for CatalogNumber----------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Generate Scorecard lookup for CatalogNumber'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName


			IF  EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[cn_disc]') AND type in (N'U'))
			drop table cn_disc

				CREATE CLUSTERED INDEX ix_date on cn_disc(txnmonth)

				select 
				convert(int,round(datekey/100,0,1)) txnmonth, 
				s.BusinessUnitId bu,
				s.CustRegCode + ' - '+ s.CustRegDesc region,
				s.salesofficecode + ' - '+s.SalesOfficedesc SalesOffice,  
				p.catalognumber, 
				sum(f.goldbookprice) goldbookprice , 
				sum(f.salesdollars) salesdollars,
				count(*) txncount
				into cn_disc
				from factorders f
				join dimproduct p
				on 
				p.productkey = f.productkey
				join dimcustomer s
				on 
				f.customerkey = s.customerkey
				where salesdollars > 0  and goldbookprice > 0
				group by 
				convert(int,round(datekey/100,0,1)), 
				s.BusinessUnitId,
				s.CustRegCode + ' - '+ s.CustRegDesc,
				s.salesofficecode + ' - '+s.salesofficedesc, 
				p.catalognumber

			set @insertcount= @@rowcount

			CREATE INDEX ix_bu			on cn_disc(bu)
			CREATE INDEX ix_product		on cn_disc(catalognumber)
			CREATE INDEX ix_region		on cn_disc(Region)
			CREATE INDEX ix_salesoffice	on cn_disc(SalesOffice)

			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Generate Scorecard lookup for CatalogNumber'


        /*--------------------------------------------------------------------------------------------*/
        /*------7. Generate Scorecard lookup for prodgroup--------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Generate Scorecard lookup for prodgroup'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

				IF  EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[pg_disc]') AND type in (N'U'))
				drop table pg_disc
				
				CREATE CLUSTERED INDEX ix_date on pg_disc(txnmonth)

				select 
				convert(int,round(datekey/100,0,1)) txnmonth, 
				s.BusinessUnitId bu,
				s.CustRegCode + ' - '+ s.CustRegDesc Region,
				s.salesofficecode + ' - '+s.SalesOfficedesc SalesOffice,  
				p.prodgroup, 
				sum(f.goldbookprice) goldbookprice , 
				sum(f.salesdollars) salesdollars,
				count(*) txncount
				into pg_disc
				from factorders f
				join dimproduct p
				on 
				p.productkey = f.productkey
				join dimcustomer s
				on 
				f.customerkey = s.customerkey
				where salesdollars > 0  and goldbookprice > 0
				group by 
				convert(int,round(datekey/100,0,1)), 
				s.BusinessUnitId ,
				s.CustRegCode + ' - '+ s.CustRegDesc ,
				s.salesofficecode + ' - '+s.SalesOfficedesc , 
				p.prodgroup

			set @insertcount= @@rowcount

			CREATE INDEX ix_bu			on pg_disc(bu)
			CREATE INDEX ix_product		on pg_disc(prodgroup)
			CREATE INDEX ix_region		on pg_disc(Region)
			CREATE INDEX ix_salesoffice	on pg_disc(SalesOffice)

			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Generate Scorecard lookup for prodgroup'


        /*--------------------------------------------------------------------------------------------*/
        /*------8. Generate Scorecard lookup for Prodline---------------------------------------------*/
        /*--------------------------------------------------------------------------------------------*/

			exec sp_logBeginSection 'Generate Scorecard lookup for Prodline'
			exec sp_logWrite @action = 'START', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@tblName = @tableName,
				@logText = @processName

				IF  EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[pl_disc]') AND type in (N'U'))
				drop table pl_disc

				CREATE CLUSTERED INDEX ix_date on pl_disc(txnmonth)

				select 
				convert(int,round(datekey/100,0,1)) txnmonth, 
				s.BusinessUnitId bu,
				s.CustRegCode + ' - '+ s.CustRegDesc Region,
				s.salesofficecode + ' - '+s.SalesOfficedesc SalesOffice,  
				p.prodline, 
				sum(f.goldbookprice) goldbookprice , 
				sum(f.salesdollars) salesdollars,
				count(*) txncount
				into pl_disc
				from factorders f
				join dimproduct p
				on 
				p.productkey = f.productkey
				join dimcustomer s
				on 
				f.customerkey = s.customerkey
				where salesdollars > 0  and goldbookprice > 0
				group by 
				convert(int,round(datekey/100,0,1)), 
				s.BusinessUnitId,
				s.CustRegCode + ' - '+ s.CustRegDesc,
				s.salesofficecode + ' - '+s.SalesOfficedesc , 
				p.prodline

			set @insertcount= @@rowcount


			CREATE INDEX ix_bu			on pl_disc(bu)
			CREATE INDEX ix_product		on pl_disc(prodgroup)
			CREATE INDEX ix_region		on pl_disc(Region)
			CREATE INDEX ix_salesoffice	on pl_disc(SalesOffice)

			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName,
				@updateCount = @updateCount
			exec sp_logEndSection 'Generate Scorecard lookup for Prodline'

/*----------------------------------END----------------------------*/

			exec sp_logWrite @action = 'STOP', 
				@logLevel = 'INFO', 
				@processName = @processName, 
				@logText = 'Successful Run', 
				@tblName = @tableName
			exec sp_logEndSection @processName

    end try
    begin catch
        exec sp_logAndRethrowError     
    end catch
end
GO

-- %% [markdown]
-- # [pricingdatamart]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [pricingdatamart] SET  READ_WRITE 
GO
